# %%
import sys
import os
sys.path.insert(0, os.path.normpath(os.getcwd() + os.sep + os.pardir))

import utils
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import pickle
from sklearn.metrics import multilabel_confusion_matrix
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class WordCountTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def transform(self, X, y=None):
        return [[len(sentence.split())] for sentence in X]
    
    def fit(self, X, y=None):
        return self
    
class CharacterCountTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def transform(self, X, y=None):
        return [[len(sentence)] for sentence in X]
    
    def fit(self, X, y=None):
        return self
    
class StopWordFrequency(BaseEstimator, TransformerMixin):
    def __init__(self, preprocessor=None):
        self.preprocessor = preprocessor
    # check this logic
    def transform(self, X, y=None):
        transformed_x = [self.preprocessor(sentence) for sentence in X]
        return [[(len(X[i])-len(transformed_x[i]))/len(X[i])] if len(X[i]) != 0 else [0] for i in range(len(X))]
    
    def fit(self, X, y=None):
        return self

# %%
pipeline = Pipeline([
    ('features', FeatureUnion([
        ('ngram', CountVectorizer(preprocessor=utils.actual_question_preprocessor)),
        ('word_count', WordCountTransformer()),
        ('character_count', CharacterCountTransformer()),
        ('setnence_remain', StopWordFrequency(preprocessor=utils.actual_question_preprocessor))
    ])),
    ('clf', RandomForestClassifier())
])

# %%
actual_question_data = utils.load_data('../data/questions.json', 'actual_question')

# %%
pipeline.fit(actual_question_data[:,0], actual_question_data[:,1])
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('ngram',
#                                                  CountVectorizer(analyzer='word',
#                                                                  binary=False,
#                                                                  decode_error='strict',
#                                                                  dtype=<class 'numpy.int64'>,
#                                                                  encoding='utf-8',
#                                                                  input='content',
#                                                                  lowercase=True,
#                                                                  max_df=1.0,
#                                                                  max_features=None,
#                                                                  min_df=1,
#                                                                  ngram_range=(1,
#                                                                               1),
#                                                                  preprocessor=<function actual_question_preprocessor at 0x1a2051...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
np.mean(cross_val_score(pipeline, actual_question_data[:,0], actual_question_data[:,1], n_jobs=-1))
# Out:
# 0.8926227040048179

# %%
param_grid = {
    'features__ngram__ngram_range': [(1,1), (1,2), (1,3)],
    'features__ngram__max_features': [None, 100, 250, 500, 1000, 1500, 2000, 2500, 3000],
    'clf__n_estimators': [100, 250, 500, 750, 1000],
    'clf__max_features': ['auto', 'log2'],
    'clf__max_depth': [None, 100, 500, 1000],
    'clf__min_samples_split': [2, 5, 10, 12],
    'clf__min_samples_leaf': [1, 2, 4, 8],
    'clf__criterion': ['gini', 'entropy'],
    'clf__bootstrap': [True, False]
}

search = RandomizedSearchCV(pipeline, param_grid, n_jobs=-1, n_iter=100)
search.fit(actual_question_data[:,0], actual_question_data[:,1])
# Out:
# RandomizedSearchCV(cv=None, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('features',
#                                               FeatureUnion(n_jobs=None,
#                                                            transformer_list=[('ngram',
#                                                                               CountVectorizer(analyzer='word',
#                                                                                               binary=False,
#                                                                                               decode_error='strict',
#                                                                                               dtype=<class 'numpy.int64'>,
#                                                                                               encoding='utf-8',
#                                                                                               input='content',
#                                                                                               lowercase=True,
#                                                                                               max_df=1.0,
#                                                                                               max_features=None,
#                                                                                               min_df=1,
#                                                                                               ngram_range=(1,
#                                                                                                            1),
#                                                                                               preproc...
#                                         'clf__max_features': ['auto', 'log2'],
#                                         'clf__min_samples_leaf': [1, 2, 4, 8],
#                                         'clf__min_samples_split': [2, 5, 10,
#                                                                    12],
#                                         'clf__n_estimators': [100, 250, 500,
#                                                               750, 1000],
#                                         'features__ngram__max_features': [None,
#                                                                           100,
#                                                                           250,
#                                                                           500,
#                                                                           1000,
#                                                                           1500,
#                                                                           2000,
#                                                                           2500,
#                                                                           3000],
#                                         'features__ngram__ngram_range': [(1, 1),
#                                                                          (1, 2),
#                                                                          (1,
#                                                                           3)]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
np.mean(cross_val_score(search.best_estimator_, actual_question_data[:,0], actual_question_data[:,1], n_jobs=-1))
# Out:
# 0.9072568503462813

# %%
search.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('ngram',
#                                                  CountVectorizer(analyzer='word',
#                                                                  binary=False,
#                                                                  decode_error='strict',
#                                                                  dtype=<class 'numpy.int64'>,
#                                                                  encoding='utf-8',
#                                                                  input='content',
#                                                                  lowercase=True,
#                                                                  max_df=1.0,
#                                                                  max_features=2000,
#                                                                  min_df=1,
#                                                                  ngram_range=(1,
#                                                                               1),
#                                                                  preprocessor=<function actual_question_preprocessor at 0x1a2051...
#                  RandomForestClassifier(bootstrap=False, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=1000, max_features='log2',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1,
#                                         min_samples_split=10,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=750, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
for question in actual_question_data:
    print(question[0])
    print(utils.actual_question_preprocessor(question[0]))
    print()
# Out:
# Questions about Part 1
# questions  part numericnumber
#
# Need help with merging from github
#    merging  sys
#
# Trouble importing my previous data structures
# trouble importing  previous data structures
#
# I need help with the iterator right now
#      iterator right
#
# We're still having trouble running the Makefile
#  still  trouble running  sys
#
# I need help figuring out what is wrong with dfs.
#    figuring    wrong  dfs
#
# when theres double letters doesnt work
#  theres double letters doesnt work
#
# longest word not returning
# longest word  returning
#
# Program runs infinitely. Tried adjusting iterator.
# program runs infinitely tried adjusting iterator
#
# argh hi this is really hard
# argh hi   really hard
#
# Having trouble transitioning from VM to GitLab.
#  trouble transitioning  sys  sys
#
# do not know what is wrong  rn
#   know   wrong rn
#
# doint know how to do recursive stuff
# doint know    recursive
#
# what is a hashcode?
#    hashcode
#
# Stuck on task 2
# stuck  task numericnumber
#
# what am i doing
#
#
# does order matter / am i tree recursive
#  order matter /   tree recursive
#
# D test fails. And now I am big sad because there are 16 people in this dang queue.
#  test fails     big sad    numericnumber people   dang queue
#
# my code segfault my code segfaults
#  code errorcode  code errorcode
#
# I'm so sorry but I'm still debugging isPrefix
# im  sorry  im still debugging camelsnakecase
#
# part 3, 4 and 5
# part numericnumber numericnumber  numericnumber
#
# C tests not passing
# c tests  passing
#
# Probably will have some issue with BST
# probably    issue  bst
#
# Memory addresses are not aligned
# memory addresses   aligned
#
# fibtest is freezing without being deadlocked
# fibtest  freezing without  deadlocked
#
# Issues with sign of numbers in stack
# issues  sign  numbers  stack
#
# compile error--possible memory leak
# compile error--possible memory leak
#
# Need help debugging my code
#   debugging  code
#
# Getting odd error
# getting odd error
#
# I am starting the project now
#   starting  project
#
# need adam's help on smth old not working
#  name   smth old  working
#
# this is tough rip
#   tough rip
#
# Mark and sweep infinite loop/cycle
# mark  sweep infinite loop cycle
#
# Dijkstra, tried writing it multiple ways
# dijkstra tried writing  multiple ways
#
# need help on B tests please help thank you
#    b tests   thank
#
# tests not working
#
#
# tests  working
#
# Need help with checking to see if a method has been called
#    checking  see   method   called
#
# m y s t e r y   s e g f a u l t
#     e r   e g f  u l
#
# Code doesn't push or commit
# code doesnt push  commit
#
# different behavior when running through valgrind vs running normally
# different behavior  running  valgrind vs running normally
#
# weird bugs wont let me compile i think its a problem with packages
# weird bugs wont let  compile  think     packages
#
# Slow performance for small linked lists
# slow performance  small linked lists
#
# weird issues with my randomSwap method: it keeps generating new characters eve
# weird issues   camelsnakecase method:  keeps generating new characters eve
#
# how do i do this
#
#
# trouble pushing to git
# trouble pushing  sys
#
# can't construct chaining hash dictionary without supplier
# cant construct chaining hash dictionary without supplier
#
# memory leak including helper functions
# AddressSanitizer: failed to read suppressions file '/home/lgriffit/cs3/project00-lgriffit/leaks.supp'
# memory leak including helper functions camelsnakecase failed  read suppressions file /home/lgriffit/cs3/project00-lgriffit/leaks supp
#
# Counting extra line when doing wc.c
# counting extra line   filename
#
# remove doesn't return previous value tried using temporary variables
# remove doesnt return previous value tried using temporary variables
#
# JSON object confusion with regards to the roads file
# json object confusion  regards   roads file
#
# Part 5 Questions
# part numericnumber questions
#
# general question about semaphore
# general question  semaphore
#
# stage 4 always giving 0s
# stage numericnumber always giving 0s
#
# I'm having trouble with part 3.
# im  trouble  part numericnumber
#
# Figuring out where concurrency issues are arising.
#
# figuring   concurrency issues  arising
#
# There's a seg fault in my coalesce function.
# theres  errorcode fault   coalesce function
#
# I have corrupted data in my garbage collector
#   corrupted data   garbage collector
#
# this is a fake question ignore me.aaa
#    fake question ignore  aaa
#
# My SSH key doesn't work.
#  sys key doesnt work
#
# Gitlab broke. We get buIlD ErrOrs. AhHhhH
# sys broke  get camelsnakecase camelsnakecase camelsnakecase
#
# how does supplier work in ChainingHashTable
#   supplier work  camelsnakecase
#
# Print_int error. I think I'm printing the memory address.
#
# camelsnakecase error  think im printing  memory address
#
# don't know how to do something
# dont know    something
#
# how to run assembly code
#
#   run assembly code
#
# Removing a key doesnt return the right value
# removing  key doesnt return  right value
#
# I have a question about my Guitar constructor.
#    question   guitar constructor
#
# mark and sweep algorithm
# mark  sweep algorithm
#
# What am I supposed to do?
#    supposed
#
# my methods dont work
#  methods dont work
#
# Issues in C tests
# issues  c tests
#
# Help with wc.c--more specifically checking a file does not exist
#   filename --more specifically checking  file   exist
#
# I accidentally signed up to work on project 4 with my lab partner the but we both wanted to work alone on this project. Could you please help me resign for this project?
#  accidentally signed   work  project numericnumber   lab partner     wanted  work alone   project could     resign   project
#
# Something's wrong with my code I think
# somethings wrong   code  think
#
# I need help with my implementation
#
#      implementation
#
# I need help debugging my linkeddeque
#    debugging  linkeddeque
#
# There's a floating point exception in my gcd code.
# theres  floating nonnumericnumber errorcode   gcd code
#
# literally no idea what to do
# literally  idea
#
# this is bad
#   bad
#
# trouble with part 8- heap buffer overflows
# asdfsdfasdfsadfasdfasdfasdfasdfsdfasfd
# trouble  part 8- heap buffer errorcode asdfsdfasdfsadfasdfasdfasdfasdfsdfasfd
#
# Rounding error in summation with circle tests polygon
# rounding error  summation  circle tests polygon
#
# buffer overflow, part 7
# buffer errorcode part numericnumber
#
# Hello my name is
# hello  name
#
# question about when
# question
#
# all of it
#
#
# Setting up the VM
# setting   sys
#
# confused on dfs
# confused  dfs
#
# Beginning questions
# beginning questions
#
# file reading and malloc
# file reading  malloc
#
# Lmao I hope I have a question by the time you get to me, the queue's just long.
# lmao  hope    question   time  get    queues  long
#
# how to test implementation/modifications in problems 3, 4, 5
#   test implementation modifications  problems numericnumber numericnumber numericnumber
#
# What's wrong with my code
# whats wrong   code
#
# victor linus chen i submit a humble request regarding your assistance
# name linus chen  submit  humble request regarding  assistance
#
# We are just confused in general
#    confused  general
#
# semaphore stuff
# semaphore
#
# the main method
#  main method
#
# coalesce doesnt seem to work  still :(
# coalesce doesnt seem  work still :
#
# I have a question about caches
#    question  caches
#
# Can't run Makefile because can't locate test_util, but it exists
#
# cant run sys  cant locate camelsnakecase   exists
#
# Help with error
#   error
#
# Can't find the bug :(
# cant find  bug :
#
# our methods have errors
#
#  methods  errors
#
# a tests yellow
#  tests yellow
#
# Lmao I hope I have a question by the time you get to me, the queue's just long so enque.
# lmao  hope    question   time  get    queues  long  enque
#
# PriorityQueue vs MinFourHeap requesting for Peter Kulitz
# camelsnakecase vs camelsnakecase requesting  name kulitz
#
# Need help
# on
#
#
#
#
#
# this is a fake question ignore me.aasdfasdf asdf
#    fake question ignore  aasdfasdf asdf
#
# Ask if I understand segmentation fits correctly and plan out implementation
# ask   understand errorcode fits correctly  plan  implementation
#
# Size complexity still not finishing even though all other tests finish quickly.
# size complexity still  finishing even though   tests finish quickly
#
# Having out of bounds errors
#    bounds errors
#
# for C tests we have assertion errors
#
#
#  c tests   errorcode errors
#
# Not running on git - access denied?
#  running  sys - access denied
#
# StackOverflowError in DFS
# camelsnakecase  dfs
#
# Having trouble finding a memory leak in bounce
#  trouble finding  memory leak  bounce
#
# ooops we have a problem
# ooops
#
# I don't quite get what the file.txt feeding into hex2raw. For buf phase1
#  dont quite get   filename feeding  hex2raw  buf phase1
#
# Proj 2 AssertionFailedErrors
# proj numericnumber camelsnakecase
#
# B test problem
# b test
#
# Oour getLowestBit is only returning zeros; we have tried going through our functions and print statements
# oour camelsnakecase   returning zeros   tried going   functions  print statements
#
# Help with sigsegv_handler
#   camelsnakecase
#
# Failing to
# failing
#
# don't know what's wrong with D tests; giving "no item matches" warnings
# dont know whats wrong   tests giving  item matches warnings
#
# help help help help help help
#
#
# I'm struggling with the Evil Hangman code. The program I wrote cannot correctly obtain a family of words based on a character guessed by the user.
# im struggling   evil hangman code  program  wrote cannot correctly obtain  family  words based   character guessed   user
#
# I require assistance with debugging.
#  require assistance  debugging
#
# My linear coalescing is giving me a segmentation fault.
#  linear coalescing  giving   errorcode fault
#
# How would we create a test for vector.c?
#  would  create  test  filename
#
#
# Need debugging help with Test B. Tried intellj debugger
#  debugging   test b tried intellj debugger
#
# Help with git clone and passphrase
#   sys clone  passphrase
#
# Have trouble with lab
#  trouble  lab
#
# i'm confused about func4
# im confused  func4
#
# No such element exception is confusing me and im not sure where it's coming from.
#   element errorcode  confusing   im  sure   coming
#
# failing on assert is_pool_address in part 3
# failing  assert camelsnakecase  part numericnumber
#
#                 _,,......_
#                  ,-'          `'--.
#               ,-'  _              '-.
#      (`.    ,'   ,  `-.              `.
#       \ \  -    / )    \               \
#        `\`-^^^, )/      |     /         :
#          )^ ^ ^V/            /          '.
#          |      )            |           `.
#          9   9 /,--,\    |._:`         .._`.
#          |    /   /  `.  \    `.      (   `.`.
#          |   / \  \    \  \     `--\   )    `.`.___
# help .;;./  '   )   '   )       ///'       `-"'
#         `--'   7//\    ///\
# _ _ - -- - _ -   -  \ \ - / \ \ \-^^^ / | / : ^ ^ ^v/ /  | |  numericnumber numericnumber / -- \ | _: _ | / /  \    | / \ \ \ \ --\   camelsnakecase  /   /// - -- 7//\ ///\
#
# finding seg fault
# finding errorcode fault
#
# Trying to understand the tests for longest
# trying  understand  tests  longest
#
# enqueue and dequeue not returning correct true/false in circularArrayTests B
# enqueue  dequeue  returning correct true false  camelsnakecase b
#
# TestCommon isn't working
# camelsnakecase isnt working
#
# help for charlotte, she cant enroll in queue
#
#   charlotte  cant enroll  queue
#
# B test is confusing and i can't get the code to compile
# b test  confusing   cant get  code  compile
#
# I don't know what's wrong...
#  dont know whats wrong
#
# array de queue help
# array de queue
#
# I'm having trouble with part 5 and am getting a stack buffer underflow.
# im  trouble  part numericnumber   getting  stack buffer underflow
#
# sort the thing help
# sort
#
# Part 4 won't make because of issue with signal handling
# part numericnumber wont make   issue  signal handling
#
# print statement in the cleanup function is not being called despite usage of fflush(stdout).
# print statement   cleanup function    called despite usage  fflush stdout
#
# How to implement a "node" as a type of element E that java will accept
#
#   implement  node   type  element e  java  accept
#
# Merging files with partner
# merging files  partner
#
# I am unable to push my code
#   unable  push  code
#
# I am having trouble figuring out how to change the value for isGameOver() in getWord()
#    trouble figuring    change  value  camelsnakecase  camelsnakecase
#
# error error error
#
# error error error
#
# For Evil Hangman should chosen word be final?
#  evil hangman  chosen word  final
#
# Conceptual help with LinkedDeque and help debugging addFront() and removeFront()
# conceptual   camelsnakecase   debugging camelsnakecase  camelsnakecase
#
# What should enque and deque do?
#   enque  deque
#
# I don't understand the remove method
#  dont understand  remove method
#
# Segfaults in my code and I don't really know why
# errorcode   code   dont really know
#
# part 8
#
# part numericnumber
#
# Having trouble with lab
#  trouble  lab
#
# help with project 01 and translate error. I posted an Ed and a TA said it had to do because of how I assigned my variables and local references. But I'm still confused
#   project numericnumber  translate error  posted  ed   ta said         assigned  variables  local references  im still confused
#
# A tests, i think my b test iterator isnt working
#  tests  think  b test iterator isnt working
#
# How do I install SDL?
#    install sys
#
# I'm not sure what to do for getWord() if we don't know what our word is in EvilHangManChooser
# im  sure     camelsnakecase   dont know   word   camelsnakecase
#
# linkeddeque iteraotr
# linkeddeque iteraotr
#
# I don't understand what to do for scene_tick. Specifications are unclear
#  dont understand     camelsnakecase specifications  unclear
#
# failing enqueue and dequeue B tests
# failing enqueue  dequeue b tests
#
# NullPointer Exceptions
# camelsnakecase errorcode
#
# We're very confused with why we're getting a heap buffer overflow.
#   confused    getting  heap buffer errorcode
#
# Assignment 4
# assignment numericnumber
#
# Coding in C
#
#
# coding  c
#
# why do I need the MTF?
#      mtf
#
# Aging policy gives me page loads of around 200000.
# aging policy gives  page loads  around numericnumber
#
# I'm not sure how to throw FileNotFounds without causing issues in the test files.
# im  sure   throw camelsnakecase without causing issues   test files
#
# How do you find the address of a reference in the pool?
#    find  address   reference   pool
#
# what
#
#
#
#
# please help! im in danger
#   im  danger
#
# Debugging Part 1, I'm trying to identify why there are AssertionFailedErrors and NoSuchElementExceptions
# debugging part numericnumber im trying  identify    camelsnakecase  errorcode
#
# Having multiple errors
#  multiple errors
#
# I don't fully understand the .ibits file
#  dont fully understand  ibits file
#
# debug pairwise. error: Segmentation fault (core dumped)
# debug pairwise error: errorcode fault core dumped
#
# how to tell if a word follows an NGram in NGramMap
#   tell   word follows  camelsnakecase  camelsnakecase
#
# Gods Plan 6969
# gods plan numericnumber
#
# My peekBack() returns a value when it's supposed to return null. I've tried outputting the reference and me when the assertEquals fails, and I think it's probably a problem with my addBack() and/or removeBack(), but I'm getting real lost when I try to figure out where I went wrong.
#  camelsnakecase returns  value   supposed  return null ive tried outputting  reference     camelsnakecase fails   think  probably     camelsnakecase and or camelsnakecase  im getting real lost   try  figure    went wrong
#
# Don't
# dont
#
# i dont know whats wrong please help lmao
#
#  dont know whats wrong   lmao
#
# NGramMap stuff debug (throwing 5 NullerPointer Exception)
# camelsnakecase  debug throwing numericnumber camelsnakecase errorcode
#
# seg faulting after all implementations are finished
# errorcode faulting   implementations  finished
#
# How do you run SubstitutionCipherSolver to decrypt cryptogram.txt?
#    run camelsnakecase  decrypt filename
#
# many problems pls halp
# many problems pls halp
#
# project 1 tests don't run or pass
# project numericnumber tests dont run  pass
#
# Looking at dequeue, it is removing the wrong thing
# looking  dequeue   removing  wrong
#
# There is something wrong with my coalesce. It isn't triggering my checkheap, and I know exactly what snippet of code is causing it (i think??)
#   something wrong   coalesce  isnt triggering  checkheap   know exactly  snippet  code  causing   think
#
# i've been sitting here for literally the past 2.5 hours please help
#
# ive  sitting   literally  past numericnumber numericnumber hours
#
# i've been sitting here for literally the past 2.75 hours please help
#
# ive  sitting   literally  past numericnumber numericnumber hours
#
# still stumped on lab 1. I'm getting a heap overflow error when I'm using strcopy,
# still stumped  lab numericnumber im getting  heap errorcode error  im using strcopy
#
# I'm on Task 2 and confused on how to go about it
# im  task numericnumber  confused    go
#
# Edit distance conceptual implementation questions
# edit distance conceptual implementation questions
#
# pls help me pls pls pls
# pls   pls pls pls
#
# intellij hangs indefinitely when running tests instead of failing normally
# sys hangs indefinitely  running tests instead  failing normally
#
# Multiple identical keys showing in NGramMap
# multiple identical keys showing  camelsnakecase
#
# Debugging adsflkjasdfoij
# debugging adsflkjasdfoij
#
# I have a question about why my two strings is not working. It seems to be repeating the first input. I have been diagraming the logic of the tostring
#    question    nonnumericnumber strings   working  seems   repeating  first input    diagraming  logic   tostring
#
# not returning the correct thing for containsKey
#  returning  correct   camelsnakecase
#
# Pls help sabrina right now.
# pls  sabrina right
#
# I'm failing some tests in Circularand am not sure why.
# im failing  tests  circularand   sure
#
# not sure about interface and not sure how to implement it
#  sure  interface   sure   implement
#
# Wondering about NGrams/how to know if NGrams are equal to each other. Just general conceptual questions
# wondering  camelsnakecase  know  camelsnakecase  equal     general conceptual questions
#
# LRU conceptual asdfafsdaf
# lru conceptual asdfafsdaf
#
# I am getting an UnsupportedOperationException error in my swap method.
#   getting  errorcode error   swap method
#
# Moving from wc.c to longest.c, I'm not very clear on if fread is doing what I think it should be doing.
# I have a while loop, where so long as we have not reached the end of the file, we continue calling fread. So here, is fread checking every single character of each line to see if it's a newline character?
# while (feof(filename) == 0) {
#       fread(buf, 1, 1, filename);
#       /* If a new line is encountered, then increment.*/
#       if (*buf == '\n') {
#         line_count += 1;
#       }
#     }
#
# moving  filename  filename im   clear   fread     think         loop   long     reached  end   file  continue calling fread    fread checking every single character   line  see    newline character  feof filename == numericnumber { fread buf numericnumber numericnumber filename /*   new line  encountered  increment */  *buf == \n { camelsnakecase += numericnumber } }
#
# D Test not iterating through hash map properly
#  test  iterating  hash map properly
#
# pls halp us we are very lost
# pls halp us    lost
#
# Part 7 debug, tried casting to 16 but integer but couldnt get to work
# part numericnumber debug tried casting  numericnumber  integer  couldnt get  work
#
# Don't really know how to implement iterator for linked list
#
#
# dont really know   implement iterator  linked list
#
# Debugging Meltdown
# debugging meltdown
#
# I'm passing all of the A tests except for the last assertion in the main test.
# im passing     tests except   last errorcode   main test
#
# ANother question
# camelsnakecase question
#
# Im really bad huinkljnklbnklbbk
# im really bad huinkljnklbnklbbk
#
# Can't get remove to work. I'm using a stack to track alphabets and nodes I've already traversed. Want to see if it works. Also, I don't think I understand the B tests conceptually at all
#
# cant get remove  work im using  stack  track alphabets  nodes ive already traversed want  see   works also  dont think  understand  b tests conceptually
#
# I am not sure what NGramMap is doing.
#    sure  camelsnakecase
#
# debugging on MTF dictionary - move to front doesn't move it to the front. Conceptual challenges with the chaining hash dictionary.
# debugging  mtf dictionary - move  front doesnt move    front conceptual challenges   chaining hash dictionary
#
# Not sure if my Graph is functioning properly (but I think it is). The MarvelTests were all "ignored" - not sure what that's about.
#  sure   graph  functioning properly   think    camelsnakecase   ignored -  sure  thats
#
# Values aren't returning the same values for peeks
# values arent returning   values  peeks
#
# Woop woop help me thanks
# woop woop   thanks
#
# My lab01 code throws a memory leak error that I'm unsure how to fix.
#  lab01 code throws  memory leak error  im unsure   fix
#
# not 100% certain that i understand what getScore is
#  100% certain   understand  camelsnakecase
#
#       _.---._    /\\
#     ./'       "--`\//
#   ./              o \          .-----.
#  /./\  )______   \__ \        ( help! )
# ./  / /\ \   | \ \  \ \       /`-----'
#    / /  \ \  | |\ \  \7--- ooo ooo ooo ooo ooo ooo
# _ --- _ /\\ / --\// /  \ ----- / /\ camelsnakecase \__ \  / / /\ \ | \ \ \ \ /----- / / \ \ | |\ \ \7--- ooo ooo ooo ooo ooo ooo
#
# Program segfaults on malloc() in the fit step, gdb says the free blocks of memory don't have proper prev/next pointers.
# Also memory is getting garbled somehow. That might be the cause of the other issue.
# program errorcode  func   fit step gdb says  free blocks  memory dont  proper prev next pointers also memory  getting garbled somehow  might   cause    issue
#
# I'm not sure how to implement the heap checker
# im  sure   implement  heap checker
#
# Gitlab cant make my code even though I can. Also, debugging for tests.
# sys cant make  code even though   also debugging  tests
#
# My checkheap isnt working. Even in essentially the given code, I get a segfault, so there might be some silly mistake in my code
#  checkheap isnt working even  essentially  given code  get  errorcode   might   silly mistake   code
#
# I am unsure how to return a new SubstitutionCipher
#   unsure   return  new camelsnakecase
#
# tips for debugging payload () overlaps another payload (); what kind of things should i print?
# tips  debugging payload overlaps another payload  kind  things   print
#
# cannot commit to github :(( changed alot of settings on my comp yesterday
# cannot commit  sys : changed alot  settings   comp yesterday
#
# check if my init is conceptually correct
# check   init  conceptually correct
#
# How do I check if a array element is empty?
#    check   array element  empty
#
# make file dumbass
# make file dumbass
#
# I'm unable to push to git because the 'master' branch is protected.
# im unable  push  sys   master branch  protected
#
# Determining if a number is negative with BNZ
# determining   number  negative  bnz
#
# victor, I need help
# name
#
# Passing tests, but Beaverchat doesn't work.
# passing tests  beaverchat doesnt work
#
# My get solution is not getting the right decryption for some reason
#  get solution   getting  right decryption   reason
#
# implementing linkeddeque (ie nodes vs linked list)
# implementing linkeddeque ie nodes vs linked list
#
# cannot find class LinkedDeque, even though I've added the file to the data structures folder
# cannot find class camelsnakecase even though ive added  file   data structures folder
#
# Understanding when a deadlock would occur
# understanding   deadlock would occur
#
# virtual memory question
#
# virtual memory question
#
# Help we broke long
#   broke long
#
# I don't know if my longest.c is correct. I just copied my code below, I'm not sure if you can see the correct format of it. I apologize. My building of a string seems fishy because from how I understand it, every character in each line is saved under 'buf', but it's all under one iteration of a loop?
#
# Moreover, this line is giving me issues: char *strcpy(char *longest_word, char *str);
# I get error: conflicting types for 'strcpy'. I know this is something silly, I'm confused with the whole reference/dereference idea.
#
# while (feof(filename) == 0) {
#       /* Assume that the longest word is no longer than 100 */
#       char *str = malloc(100 * sizeof(char));
#       fread(buf, 1, 1, filename);
#
#       /* Build string for every new work encountered */
#       while (*buf != '\n' || *buf != ' ') {
#         for (int i = 0; i < 100; i++) {
#           str[i] = *buf;
#         }
#       }
#
#       /* Update max word count and longest word variables when applicable */
#       if (strlen(str) > max_wc) {
#         max_wc = strlen(str);
#         char *strcpy(char *longest_word, char *str);
#       }
#     }
#  dont know   filename  correct   copied  code  im  sure    see  correct format    apologize  building   string seems fishy     understand  every character   line  saved  buf     nonnumericnumber iteration   loop moreover  line  giving  issues: char *strcpy char *longest_word char *str  get error: conflicting types  strcpy  know   something silly im confused   whole reference dereference idea  feof filename == numericnumber { /* assume   longest word   longer  numericnumber */ char *str = malloc numericnumber * sizeof char fread buf numericnumber numericnumber filename /* build string  every new work encountered */  *buf = \n || *buf =   {  int  = numericnumber  < numericnumber i++ { str[i] = *buf } } /* update max word count  longest word variables  applicable */  strlen str > camelsnakecase { camelsnakecase = strlen str char *strcpy char *longest_word char *str } }
#
# Trying to figure out how to store array of strings within data parameter of strarray but to no avail; have tried messing with how words are generated or string is read, solution still not generated. Also asan does not throw any errors which is making this more confusing.
# trying  figure    store array  strings within data parameter  strarray    avail  tried messing   words  generated  string  read solution still  generated also asan   throw  errors   making   confusing
#
# For ChainingHashDictionary all of our tests pass but the complexity tests run very long.  We have tried making MoveToFrontDictionary as quick as possible so it could be an issue with our hashCode or equals.
#  camelsnakecase    tests pass   complexity tests run  long   tried making camelsnakecase  quick  possible   could   issue   camelsnakecase  equals
#
# I'm not sure how to allocate memory for the char ** struct in lab01. Do I only need to allocate memory for the char * pointers or do I need to allocate all the memory that I will need?
# im  sure   allocate memory   char ** struct  lab01      allocate memory   char * pointers      allocate   memory
#
# We get an error about the #include sdl_wrapper.h line when we try to compile our pacman.c file.
#  get  error   #include camelsnakecase line   try  compile  filename file
#
# I have no strong conceptual understanding of what this assignment is even asking for. What does it even mean for a dictionary to have a
#    strong conceptual understanding    assignment  even asking     even mean   dictionary
#
# I added the code pasted below to my vector.c file, but I'm getting incomplete definition of type 'struct vector' errors when I create a test file. I'm not sure what else I have to do to complete the definition
#
# typedef struct vector {
#   double x;
#   double y;
# } vector_t;
#
#  added  code pasted    filename file  im getting incomplete definition  type struct vector errors   create  test file im  sure  else      complete  definition typedef struct vector { double x double  } camelsnakecase
#
# Not sure how to implement removeBack() method for LinkedDeque in constant time
#  sure   implement camelsnakecase method  camelsnakecase  constant time
#
# CLOCK/LRU policy?
# clock lru policy
#
# return statement
# return statement
#
# void * stuff
#
#
# void *
#
# The final B test times out. I'm trying to figure out why the put and get methods are taking so long.
#  final b test times  im trying  figure    put  get methods  taking  long
#
# My longest word code fails the empty test, even though I check for this condition.
#  longest word code fails  empty test even though  check   condition
#
# tests passing locally but not on gitlab
# tests passing locally    sys
#
# Am I supposed to include
#
# "#ifndef VECTOR_H
# #define VECTOR_H"
#
# at the top of my  vector.c like it is on top of vector,h
#   supposed  include #ifndef camelsnakecase #define camelsnakecase   top   filename like    top  vector h
#
# i don't know how to use the Sorted Set and how to load the words from
#  dont know   use  sorted set    load  words
#
# chris help please send some help brother
# chris   send   brother
#
# im bad
# im bad
#
# not passing github test, but all tests passing on local computer
#
#  passing sys test   tests passing  local computer
#
# adam help please send some help brother
# name   send   brother
#
# When I do not flush out the pages from the cache, I still get that one index is consistently the best.
#     flush   pages   cache  still get  nonnumericnumber index  consistently  best
#
# Question.
# question
#
# othello question
# othello question
#
# I keep getting an error with initializing a final field in the constructor and noSuchElementException
#  keep getting  error  initializing  final field   constructor  errorcode
#
# LinkedDeque has 37/43 tests passing. My contains() tests are not working, I believe an index may be off by 1 somewhere.
# camelsnakecase  37 43 tests passing  func tests   working  believe  index may    numericnumber somewhere
#
# peter u better get your ass over here
#
# name u better get  ass
#
# number of lines wc.c part
# tests give an error "no new line at end of file"
# number  lines filename part tests give  error  new line  end  file
#
# How long should decrypting crytogram.txt take in Sub Cipher Solver? Also, I need help committing my code to GitHub.
#  long  decrypting filename take  sub cipher solver also    committing  code  sys
#
# My code for AIHangmanGuesser fails the final case of the tests by being off by one letter and I am not sure why.
#  code  camelsnakecase fails  final case   tests     nonnumericnumber letter     sure
#
# For assignment 3, how do I write a case that can take in i_iconst* (instead of having to explicitly write out i_iconst_[m1, )?
#  assignment numericnumber    write  case   take  camelsnakecase instead    explicitly write  camelsnakecase
#
# I have some difficulties passing the Test main() instance [3] for C Test and generally Test main() for B Test. I also have some question about the last part (Decrypting cryptogram.txt and )
#    difficulties passing  test func instance [3]  c test  generally test func  b test  also   question   last part decrypting filename
#
# Meltdown is recognizing characters that are not in kernel string at similiar ratios to those that are in kernel space. I have tried varying the ratio I use, but any value below the one I get from stats-q1 preforms similarly (I vary the ratio by .5). I have also set the ith page to be
# meltdown  recognizing characters     kernel string  similiar ratios      kernel space   tried varying  ratio  use   value   nonnumericnumber  get  stats-q1 preforms similarly  vary  ratio  numericnumber   also set  ith page
#
# not returning the correct boolean for containsKey and not sure if I understand debugging tests
#  returning  correct boolean  camelsnakecase   sure   understand debugging tests
#
# For projet 2, I tried to use some print statements and I'm not sure why the first time I try to print a pattern it seems to always start with aa.
#  projet numericnumber  tried  use  print statements  im  sure   first time  try  print  pattern  seems  always start  aa
#
# Every test passes for the MoveToFrontDictionary tests except for the size tests. My size seems to be one less than expected for each test. I've tried using a debugger and tracing my code but I cannot seem to figure it out.
# every test passes   camelsnakecase tests except   size tests  size seems   nonnumericnumber less  expected   test ive tried using  debugger  tracing  code   cannot seem  figure
#
# Getting a segfault when returning for after popping all values into registers
# getting  errorcode  returning   popping  values  registers
#
# I don't understand how to use the different interfaces and data types.
#  dont understand   use  different interfaces  data types
#
# use equals or ==
# use equals  ==
#
# I am getting an error that says I might not have initialized the final word. I have private final String wordToGuess; and tr
#   getting  error  says  might   initialized  final word   private final string camelsnakecase  tr
#
# Need clarification on an error and on Hash code
# Failing tests for the data that has booleans but not the data that has ints
#  clarification   error   hash code failing tests   data   booleans    data   ints
#
# I have found a bug in the way my code is running a certain function, but do not understand how to fix it or why it is working that way
#   found  bug   way  code  running  certain function    understand   fix      working  way
#
# My size function isn't working, even though when I put a print statement in it to check I'm getting the same value that the tests are expecting.
#  size function isnt working even though   put  print statement    check im getting   value   tests  expecting
#
# I do not know why I have an off-by-one error on my encodetext. Also, i do not undersatnd part of the
#    know     nonnumericnumber error   encodetext also    undersatnd part
#
# Regarding an error message(main is usually not a non-static function)
# regarding  error message main  usually   non-static function
#
# peter help send some help please i love you
# name  send     love
#
# I'm getting a stack buffer overflow error when I run test7 and I'm not sure why
# im getting  stack buffer errorcode error   run test7  im  sure
#
# Am I supposed to loop through the file of word everytime I create a new random hangman chooser?
#   supposed  loop   file  word everytime  create  new random hangman chooser
#
# I tried to test wc.c on dictionary.txt and have the following problems:
# wc.c:14:18: warning: implicitly declaring library function 'malloc' with type 'void *(unsigned long)'
#       [-Wimplicit-function-declaration]
#   char *result = malloc(number_to_read * sizeof(char));
#                  ^
# wc.c:14:18: note: include the header <stdlib.h> or explicitly provide a declaration for 'malloc'
# wc.c:18:5: warning: implicit declaration of function 'free' is invalid in C99 [-Wimplicit-function-declaration]
#     free(result);
#     ^
# wc.c:24:18: warning: result of comparison against a string literal is unspecified (use strncmp instead)
#       [-Wstring-compare]
#       if (result == "\n") {
#                  ^  ~~~~
# 3 warnings generated.
# /usr/bin/ld:data/dictionary.txt: file format not recognized; treating as linker script
# /usr/bin/ld:data/dictionary.txt:2: syntax error
# clang-5.0.1: error: linker command failed with exit code 1 (use -v to see invocation)
#  tried  test filename  filename    following problems: filename :14:18: warning: implicitly declaring library function malloc  type void * unsigned long  [-wimplicit-function-declaration] char *result = malloc camelsnakecase * sizeof char ^ filename :14:18: note: include  header filename >  explicitly provide  declaration  malloc filename :18:5: warning: implicit declaration  function free  invalid  c99 [-wimplicit-function-declaration] free result ^ filename :24:18: warning: result  comparison   string literal  unspecified use strncmp instead [-wstring-compare]  result == \n { ^ ~~~~ numericnumber warnings generated filename : file format  recognized treating  linker script filename :2: syntax error clang-5 numericnumber 1: error: linker command failed  exit code numericnumber use -v  see invocation
#
# My code is returning an inverted array of the array expected, and I want to make sure I am implementing my methods in the correct way.
#  code  returning  inverted array   array expected   want  make sure   implementing  methods   correct way
#
# I have an error in my main function for the C tests though all the method tests have passed.
#    error   main function   c tests though   method tests  passed
#
# I am unable to figure out why one of the test cases failed. I tried to debug but I cannot see the error. I tried looking at what the variables hold, but it appears to be correct so far.
#   unable  figure   nonnumericnumber   test cases failed  tried  debug   cannot see  error  tried looking    variables hold   appears   correct  far
#
# Why are push and pop constant time but enqueue and dequeue linear time? They're both relying on the add and remove helper functions which are linear time. Also, my removeBack is causing index errors in the tests but I can't recreate it with my own code or find the error by running through the code in my head.
#   push  pop constant time  enqueue  dequeue linear time theyre  relying   add  remove helper functions   linear time also  camelsnakecase  causing index errors   tests   cant recreate     code  find  error  running   code   head
#
# remove problem help
# remove
#
# I'm not sure why my hangman guesser code does not input the letter with the highest frequency.
# im  sure   hangman guesser code   input  letter   highest frequency
#
# don't understand when to use static
# don't understand when a pointer is char * or void *
# dont understand   use static dont understand   pointer  char *  void *
#
# I'm confused about which end enqueue and dequeue add to for . It seems like if enqueue adds to the front I pass the stress tests but not toString, but if I add to the back it passes toString but not stress test.
# im confused   end enqueue  dequeue add    seems like  enqueue adds   front  pass  stress tests   camelsnakecase    add   back  passes camelsnakecase   stress test
#
# Not sure how to use my static final RANDOM to correctly generate the word that each test wants.
#  sure   use  static final random  correctly generate  word   test wants
#
# B: Edge case not working. (The Avengers Premiere will show up in complete(), but not The Avengers itself (search term)).
# b: edge case  working  avengers premiere  show   func    avengers  search term
#
# Hangman Guesser doesn't find any words matching pattern.
# hangman guesser doesnt find  words matching pattern
#
# BST dictionary understanding
# bst dictionary understanding
#
# problems with making field with stored word final
# problems  making field  stored word final
#
# Wc.c compiles but says there is a memory leak and I cannot find it.
# filename compiles  says    memory leak   cannot find
#
# My coalescing is not working, and I've spent a ton of time on it, and am not sure why...
#  coalescing   working  ive spent  ton  time      sure
#
# Getting a segfault when returning for sthread_restore, after popping all values into registers
# getting  errorcode  returning  camelsnakecase  popping  values  registers
#
# AI Guesser is passing some test cases, but fails at a certain point.
# ai guesser  passing  test cases  fails   certain nonnumericnumber
#
# Are we supposed to make changes to the other test files? Also, we have a lot of warnings from the free function.
#   supposed  make changes    test files also    lot  warnings   free function
#
# I wouldve had a more specific question if my computer hadnt just died with no battery, but basically Im wondering if Im doing something stupid when doing the last part of the project to decrypt the text file. What Ive thought if so far is to do some I/O stuff so I can store the file line by line and then use the pre-made substitution cipher solver, which takes input from system.out. Im just not sure if Im doing this in a stupid, overly complicated way, or if Adam just wants us to figure out a bunch of stuff on our own. I dont know if that made any sense. Ive never used java before.
#  wouldve    specific question   computer hadnt  died   battery  basically im wondering  im  something stupid    last part   project  decrypt  text file  ive thought   far     i o     store  file line  line   use  pre-made substitution cipher solver  takes input  system  im   sure  im     stupid overly complicated way   name  wants us  figure   bunch       dont know   made  sense ive never used java
#
# Why does the first block go at mem_heap_lo() + 8?
#    first block go  camelsnakecase + numericnumber
#
# util is quite low but throughput is 20/20! tips on improving util?
# util  quite low  throughput  20 20 tips  improving util
#
# God bless me cskdhfncej
# god bless  cskdhfncej
#
# Help I need!!!
#
#
# getting errors on git not sure why
# getting errors  sys  sure
#
# not sure why the put is returning null instead of " "
#  sure   put  returning null instead
#
# I am debugging my peek function. I made sure to be looking at the last element of the stack.
#   debugging  peek function  made sure   looking   last element   stack
#
# I'm not sure why my pluck() method is not passing the tests. It seems to be working correctly.
# im  sure   func method   passing  tests  seems   working correctly
#
# Not sure if I'm getting the right graphs after implementing the badcache optimization.
#  sure  im getting  right graphs  implementing  badcache optimization
#
# Getting null for  addFront/addBack removeFront/removeBack
# getting null  camelsnakecase camelsnakecase
#
# still same problem lmao
# still   lmao
#
# General help.
#
#
# general
#
# General help
#
# general
#
# My code for wc.c seems to work when I test it interactively, but when I run the test, it says execution error and I'm not sure what to look for.
#  code  filename seems  work   test  interactively    run  test  says execution error  im  sure   look
#
# For the wc program I pass all the tests except the empty test for which I get the error - Execution error. In addition, for the longest program I could use some help with memory leaks - I need to free up some memory but also return it from function.
#   wc program  pass   tests except  empty test    get  error - execution error  addition   longest program  could use    memory leaks -    free   memory  also return   function
#
# I have to copy the definition of struct vector into my testing file, in addition to vector.c, to avoid "incomplete definition" errors. In the lab, we put it in the header so we didn't have to repeat code. Is that a better way to do this? Or should I put it in both places?
#    copy  definition  struct vector   testing file  addition  filename  avoid incomplete definition errors   lab  put    header   didnt   repeat code    better way       put    places
#
# we love you jessie
#  love  jessie
#
# Project 8 with a late token. The C tests are almost working, but the "Nodes and Edges" test fails with a IllegalArgumentException in my neighbors() function (i.e. it calls for a vertex that apparently does not exist in my graph).
# project numericnumber   late token  c tests  almost working   nodes  edges test fails   errorcode   func function  e  calls   vertex  apparently   exist   graph
#
# started lab recently, working on constructor and trying to create a sorted set. Not sure how to access dictionary text file provided
# -where to initialize current guesses?
# -reading in dictionary scrabble.txt, what are the keys and values? just words?
# -check highlighted errors
#
# -accessing the
# started lab recently working  constructor  trying  create  sorted set  sure   access dictionary text file provided -where  initialize current guesses -reading  dictionary filename    keys  values  words -check highlighted errors -accessing
#
# extra line hlepp asdf
# extra line hlepp asdf
#
# The return values of my peeks are not equal, though I made sure the top of the stack was the same as the front of queue.
#  return values   peeks   equal though  made sure  top   stack      front  queue
#
# we love u adam
#  love u name
#
# Unsure why payload overlaps
# unsure  payload overlaps
#
# hi last program pls
# hi last program pls
#
# The CMS server is taking a really long time to put files on atom. Just checking if there is a current issue? I put the command atom longest.c and it hasn't done anything for like 3 min.
#  cms sys  taking  really long time  put files  atom  checking     current issue  put  command atom filename   hasnt done anything  like numericnumber min
#
# just help me please
#
#
# When testing for fibonacci, it seems like mine just copies the given value to register 2 but I wasn't sure why it was doing that?
#  testing  fibonacci  seems like mine  copies  given value  register numericnumber   wasnt sure
#
# I created some tests in my Main for addFront/addBack and they work as expected when I add a small number of elements, but they are not passing the LinkedDeque tests.
#
# My removeBack is not working and not sure why, currently debugging.
#  created  tests   main  camelsnakecase   work  expected   add  small number  elements     passing  camelsnakecase tests  camelsnakecase   working   sure  currently debugging
#
# I think all the tests pass except for algo_csum.py, which loops infinitely. I've tried removing the while loop and only checking the first allocated block, but even then it loops infinitely.
#  think   tests pass except  camelsnakecase  loops infinitely ive tried removing   loop   checking  first allocated block  even   loops infinitely
#
# Getting errors on 'empty' for both wc.c and longest.c. Running valgrind shows it's not a memory leak but instead is "Conditional jump or move depends on uninitialised value(s)". My guess is that it comes from when I call buffer[0] or something, but I'm not sure why.
# getting errors  empty   filename  filename running valgrind shows    memory leak  instead  conditional jump  move depends  uninitialised value    guess    comes    call buffer[0]  something  im  sure
#
# Casting stuffaaaaaaaaaaaa
# casting stuffaaaaaaaaaaaa
#
# Having problems with the runtime of algorithms NFU and aging, as output is correct but it takes hours to finish running them. I've looked at all of the loops but couldn't see anything that would cause long-running loops.
#  problems   runtime  algorithms nfu  aging  output  correct   takes hours  finish running  ive looked     loops  couldnt see anything  would cause long-running loops
#
# We are mallocing the cache in the main thread of proxy.c so that the same cache can be access across multiple threads. Where can we free the cache since the logical place to do so would be after the while loop in the main method, but that location is never reached.
#   mallocing  cache   main thread  filename     cache   access across multiple threads    free  cache since  logical place    would     loop   main method   location  never reached
#
# Wondering how to properly parse the files in BeaverMapsGraph. I've attempted to implement the example on the spec of course, but I'm not sure how to translate this method over the waypoint and road files.
# wondering   properly parse  files  camelsnakecase ive attempted  implement  example   spec  course  im  sure   translate  method   waypoint  road files
#
# My put method is not giving the right size after being called, and I want to make sure I am understanding the method right.
#  put method   giving  right size   called   want  make sure   understanding  method right
#
# Getting OutOfMemory error for iterators. I can't seem to figure out why it's doing that and I suspect that it's probably the iterator is continuously looping over the next element and not stopping at all.
# getting camelsnakecase error  iterators  cant seem  figure        suspect   probably  iterator  continuously looping   next element   stopping
#
# Currently, the Dijkstra tests are reporting that they are finding longer paths than they are supposed to, or not at all. I have tried running the debugger on the Dijkstra algorithm and checked my minFourHeap, but no immediately apparent problem appears.
# currently  dijkstra tests  reporting    finding longer paths    supposed        tried running  debugger   dijkstra algorithm  checked  camelsnakecase   immediately apparent  appears
#
# need fix
#  fix
#
# How can we determine if the file "f" has more characters and if the character read is a newline? My first inclination was to use the fef() method, however we this would not allow for the reading of two characters at a time (as in the case of a newline)
#    determine   file f   characters    character read   newline  first inclination   use  func method however   would  allow   reading  nonnumericnumber characters   time    case   newline
#
# Everything just changed with that one small revision. The issue I was going to post to CampusWire is gone. Now only two tests fail (that I can see): the test on "random graphs and paths" gives a wrong answer for the length, and the test on caltech data throws an IllegalArgumentException in decreaseKey(), claiming that the worklist does not contain some location.
# everything  changed   nonnumericnumber small revision  issue   going  post  camelsnakecase  gone   nonnumericnumber tests fail    see :  test  random graphs  paths gives  wrong answer   length   test  caltech data throws  errorcode  camelsnakecase claiming   worklist   contain  location
#
# intellij hates me
# sys hates
#
# Assembly that should be compiling is not, which appears to be a slight is, and phantom newlines are appearing. These are likely fairly basic issue with the way things are setup, though I cannot get around them.
# assembly    compiling    appears    slight   phantom newlines  appearing   likely fairly basic issue   way things  setup though  cannot get around
#
# fuk you jeff
# fuk  jeff
#
# Please help we're so confused
#     confused
#
# errors! errors!
# errors errors
#
# Analysis questions, specifically differences between operating systems, etc
# analysis questions specifically differences  operating systems etc
#
# god save me
# god save
#
# Looking through
# looking
#
# We are getting an IllegalArgumentException (stemming from neighbors method in Graph) for our test nodes and edges case. However, we checked that the node that is supposed to be missing is there with its correct neighbors. We aren't sure if our constructor or ChainingHash class is incorrect.
#   getting  errorcode stemming  neighbors method  graph   test nodes  edges case however  checked   node   supposed   missing     correct neighbors  arent sure   constructor  camelsnakecase class  incorrect
#
# yuh ayyuh yuhay
# yuh ayyuh yuhay
#
# nothing works ree
#
# nothing works ree
#
# peter send help
# name send
#
# Please help me
#
#
# errors asdf
#
#
#
# errors asdf
#
# Help
#
#
#
#
# Help
#
#
# kinda confused
#
#
# kinda confused
#
# what's wrongggggggggg
# whats wrongggggggggg
#
# MELTDOWN MELTDOWN MELTDOWN
# meltdown meltdown meltdown
#
# pls help hhhhh
# pls  hhhhh
#
# God bless mecskdhfncej
# god bless mecskdhfncej
#
# Help please
#
#
#
# lmao help please
#
# lmao
#
# Just starting-
#  starting-
#
#
#
#
#
#
#
#
#
#
# infinite loops
#
# infinite loops
#
# fairness
# fairness
#
# Errrorrrrrrrrrrrrrrr
# errrorrrrrrrrrrrrrrr
#
# bits      mndfsbsfbsfba
#
#
# bits mndfsbsfbsfba
#
# keySet
#
# camelsnakecase
#
# I
#
#
#
# TrieMap Movie Autocompleter
# camelsnakecase movie autocompleter
#
# malloc problem
# malloc
#
# Extra credit
# extra credit
#
# Bug.
# bug
#
# SO MUCH
#  much
#
# fixing meltdown
# fixing meltdown
#
# Halp
# halp
#
# IsPrefix()
# camelsnakecase
#
# ASDAsdASDAsdASDAsdADASDAsd
# camelsnakecase
#
# Pls t
# pls
#
# sdgsf
# sdgsf
#
#  nnn
# nnn
#
# HELLO
# hello
#
# Hello
#
# hello
#
# ...
# ...
#
# Spring Force
# spring force
#
# spring force
# spring force
#
# Json
#
# json
#
# jeff sucks
# jeff sucks
#
# chaininghashdictionary issues
# chaininghashdictionary issues
#
# HALP PLS
# halp pls
#
# starting minfourheap
# starting minfourheap
#
# TrieMap broke.
# camelsnakecase broke
#
# Json issues
# json issues

# %%
res = []
with open('../data/questions.json', 'r') as f:
        res = np.array([utils.remove_non_ascii(eval(data_point)['question']) for data_point in f.read().splitlines()])

# %%
for question in res:
    if search.best_estimator_.predict([question]) == 't':
        print(question)
        print()
# Out:
# All sorts of issues with peekFront
#
# neighbors being weird in beaver map graph
#
# Need help with merging from github
#
# Unsure about some thread functions
#
# trying to get star to work
#
#
# Question about remove method implementation
#
# Not pushing to git.
#
# questions about segregated storage
#
# "error: typedef redefinition with different types"
#
# Histogram has a lot of noise, causing errors.
#
# Where do I start with garbage collector?
#
# size isn't updating correctly in ChaininHashDictionary
#
# Having trouble writing the randomly initialized key
#
# Several quick conceptual questions.
#
# NullPointerException on add() functions
#
# Clarification on stack frame question
#
# Dikstra Doesnt work on map
#
# Dijkstra doesn't work on map
#
# graph implementation does not work
#
# MinFourHeap and conceptual ngrammap
#
# help on lab- error with deserialization
#
# BST Dictionary debugging
#
# MoveToFront dictionary not working
#
# confirming ideas about spec about spec about spec mgjrieafgjf
#  erg
# grjgierbs
# t
# n
# nr
# s
# n
# sfn
# ts
# hte
# hejhtsehjkel;
#
#
# I'm having trouble constructing the ArrayDeque
#
# Trouble importing my previous data structures
#
# Trouble importing my previous data  structures
#
# can't figure out null pointer exception
#
# What is chunksize (also pls help me debug)
#
# ArrayDeque class- issues with peekFront running constant time as well as importation errors with testing.
#
# ensuring capacity of backing data structure
#
# put method in MoveToFront Dictionary
#
# I need advice optimizing my splay tree.
#
#
# We're still having trouble running the Makefile
#
# Does setting this.previous = null set this.previous.next = null
#
# please help us the test is being mysterious
#
# I need help figuring out what is wrong with dfs.
#
# when theres double letters doesnt work
#
# making a new class with intelliJ
#
# trying to get memmove to work (q4)
#
# More error messages from mystring.c
#
# Trying to set up vm graphics.
#
# I need help with the equals method
#
# having trouble with the compareTo method
#
#
# Having trouble initializing updating the current TrieNode
#
# question about heap buffer overflow (again )
#
# longest word not returning
#
# NullPointerExceptions triggered by our resize() method
#
# question about command line arguments i think
#
# I'm still seg faulting. I think I somewhat fixed coalescing
#
# I have some miscellaneous questions
#
# object type trouble with C Tests
#
# i'm stuggling to set up a private variable
#
# trying to run hangman game
#
# Need help with dfs for finding locations
#
# Are haivng problems with linker command failed
#
# Clarifying questions throughout the assignment
#
# testing the branch_unit and branching_program_counter
#
# not passing D tests help please
#
# need help getting garbage collector to work
#
# Just wanted to confirm....did I really do recursion? (gcd)
#
# seg list slower than explicit list
#
# Program runs infinitely. Tried adjusting iterator.
#
# I need help writing the remove back method
#
# A compilation error with stage 3.
#
# B tests help with adding onto titles trie
#
# clarification on seg fault handler
#
# Clarifying questions throughout the set
#
# My constructor for RandomHangman
#
#
# Project 4 part D complete method
#
# removing a letter from a file
#
#
# Having trouble transitioning from VM to GitLab.
#
# question about dereferencing constant pool (pt6)
#
# Having trouble with assigning values to rdi
#
# trying to use setz
#
# I need help w the equals() method
#
# We're having trouble running the Makefile
#
# randomly getting one negative value
#
# B Move to Front constructor. Thanks!
#
# I'm just having a somewhat hard time wrapping my head around this assignment.
#
# trouble with part 7
# sometimes null pointer errors, sometimes heap buffer overflows
#
# question regarding removing BST nodes
#
# Chaining hash dictionary iterator
#
# can't find problem in randomizing pluck() method
#
# Explaining locks / unlocks in code
#
# Trouble shooting errors in C test.
#
# Generating and interpreting the plots
#
# Help debugging / conceptualizing makeGuess() in Evil Hangman
#
# help setting next and previous blocks
#
# constructor of Arraydeque and linkedDeque
#
# really quick thing about command line arguments
#
# trouble with page-loads seg faults in FIFO
#
# trouble with page-loads seg faults in CLRU
#
# SIGTRAP error arising from confusing location
#
# MinFourHeap increase and decrease key methods
#
# writing a program for branching processor
#
# Address Sanitizer issue with remainder function
#
# Finishing off assignment, design questions
#
# C tests help with debugging tests
#
# Broad approach for implementing ChainingHashDictionary
#
# remove method not removing properly
#
# Segregated list not improving throughput
#
# Something wrong with assembly code in glue.s
#
# Test6 failing for unknown reason
#
# having issues with iterator in chaininghash
#
# Book Problem 3.63 confused about machine code with 00 line.
#
# Seg fault in simple realloc optimization :'(
#
# what is a hashcode?
#
# I need help debugging evil hangman
#
# Ratios are confusing for index-guesser
#
# I need help figuring out what is wrong with remove.
#
# don't understand what constitutes initialization
#
#
#
# I need help with the invokestatic method
#
# questions about incref() in collect_garbage
#
# questions about decref() in collect_garbage
#
# Question about self-cycle in last part
#
# having issues with my recursion task 1
#
# trying to understand glue.s
#
# I don't really understand LinkedLists
#
# Need help understanding pairwise summation
#
# Cant iterate through entire list effectively
#
# style & also the stackframe.txt
#
# Project 1 signup, petition to work alone
#
# B tests help we need aome conceptual help
#
# 3rd exploit misread string contains more characters than my cookie contains
#
# Keyhandler affecting stuff outside of it
#
# C tests help with the percolate down
#
# Need help with understanding gerrymandering.
#
# Stack overflow error with dequeue.
#
# vector.c "linker command failed" error?
#
# Can't push code to git
#
# Having trouble recursively calling put method.
#
# Lab3. issue with pixel bit assignment
#
# the chaining hash dictionary construction
#
# I need help with the hashcode on chaininghashmap
#
# weird error we think we t
#
# lmao help please sanity test is testing my sanity
#
#
# private method for play() method
#
#
# having issues with storing in psol.txt
#
# I'm confused about the initialize_context concept --
#
# Getting started with graph implementation
#
# I need help with understanding c
#
# I need help with understanding topksort
#
# Trouble with assertions in eval.c
#
# Being told I need to install developer tools
#
# Make sure I understand hashcode
#
#
#  Small bug in test B completions
#
# Getting a NoSuchMethodException in ChainingHash
#
# Clarification of conceptual questions
#
# I'm having a lot of index problems
#
# Init and functionality of malloc
#
# abstract vec_list functions still not working
#
# we have a quick question about priority
#
# Non-constant time for push/pop()
#
# missing some neighbors on waypoints
#
# Trouble with the djikstra method timing out
#
# Null Pointer exceptions in LinkedDeque
#
# debugging for gc, compile errors
#
# Having issues with iterator in LinkedDeque
#
# Help debugging CircularArrayFixedSizeQueue from Project 3
#
# Confused about name for function pointer for foreach_global
#
# forbidden import and weird size problem
#
# Confused about reading kernel for meltdown
#
# Want some clarification on BSTDictionary
#
# never uses the semaphore function
#
# Debugging the movetoFront dictionary
#
#
# Precision error with Accurate summation with partials algorithm
#
# How to interpret perf-iter plateau?
#
# iterating over sorted set thats in a map
#
# Making code atomic in glue.s (lock/unlock functions)
#
# I'd appreciate help figuring out where some of these NullPointerExceptions are coming from
#
# Not returning correct output value
#
# We are confused about generic pointer types in C
#
# Running general ideas by/talking out data structure
#
# I would like to hack countable thoughts.
#
# mm_checkheap segfaulting when program otherwise gets perfect score
#
# Conceptual question about page access
#
# memory problems on longest.c
#
# AI Hangman Null Pointer Exception
#
# my contains key still runs forever
#
# casting stuff (Vector to void *) continues to plague us
#
# handling segmentation faults in stage 4
#
# LinkedDeque iterator next() method and
#
# Question 1 and Vm Question
#
# B tests rehashing might be wrong
#
# Getting confused on starting project00
#
#
# Problem 5: conditional movs and common theme
#
#
# percolate down issues-- not entering conditional block
# I need help ensuring all methods are implemented properly
#
#
# Problem with getting rsp location.
#
# oh no :( we are failing something weird
#
# Asking about assembly code in math.annotated.s
#
# Git tests are pending
#
# Just confused about how movetodictionary works
#
# a tests confusion about algorithm
#
# I need help with understandingwhat getSolution is doing
#
# stress tests, assertion failed errors
#
# project 5 error caused by ArrayDeque?
#
# What does hashcode do
#
# ArrayDeque class- issues with peek running constant time
#
# My LinkedDeque is completely broken.
#
# Linked deque iterator implementation
#
# ChainingHashDictionary tests not running
#
# I need help debugging the edit distances method
#
# Types in TrieMap AutoCompleter for complete()
#
# Restructuring the way we iterate through our data
#
# can I get some help understanding "puts"
#
# Need help understanding __sthread_initialize_context(stack, f, arg)
#
# Footer issues not matching with size.
#
# confused on working with ssh machine
#
# Confused about using function in thread initialization
#
# ssh copy aint workin on this sad sad day
#
# question about part two: stack pointers
#
#
# move to front dictionary put/get/remove
#
# help with lab 01....having memory error
#
# efficiency of 8byte pointers vs 4 byte pointers
#
# linked deque tests not running
#
# seg fault in free (inputting a pointer smaller than _heap_lo
#
# Having trouble compiling the graphic library & using the vm
#
# intellij is not working again
#
#
#
# confused about increaseKey and decreaseKey
#
# All sorts of issues with removeFront/removeBakc peekFront
#
# last test on Movetofrontdictionary
#
#
# I need help setting up the the VM.
#
# i need help understanding the btests.
#
# Need help reading error messages from mystring.c
#
# longest word and vectors
#
# parameters for segregated free list
#
# clarifying question on crytogram.txt part
#
# Help with testing vectors and main
#
# conceptually unsure what stretch goal wants
#
# BST dictionary remove
#
# having trouble retrieving values from list (Object type)
#
# having trouble with the put method
#
# Seem to be having issues adding elements
#
# containsValue and complete function
#
# Still attempting to implement Chaining Hash Dictionnary
#
# are addresses supposed to be pointers?
#
# Trouble with getCompletions... and containsKey
#
# Finishing up C tests/beginning B tests

# %%
for question in res:
    if search.best_estimator_.predict([question]) == 'f':
        print(question)
        print()
