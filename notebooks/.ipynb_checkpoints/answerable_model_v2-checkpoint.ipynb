# %%
import sys
import os
sys.path.insert(0, os.path.normpath(os.getcwd() + os.sep + os.pardir))

# %%
import utils
import numpy as np
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, make_scorer, roc_auc_score
from model_training import WordCountTransformer, CharacterCountTransformer, StopWordFrequency

# %%
answerable_data = utils.load_data('../data/aqfiltered.json', 'answerable')

# %%
stop_words = set(stopwords.words('English'))

# %%
def answerable_preprocessor(sentence):
    sentence = utils.check_quotations(sentence)
    sentence = word_tokenize(sentence)
    
    for i in range(len(sentence)):
        sentence[i] = utils.check_backslash(sentence[i])
        sentence[i] = utils.check_camel_snakecase(sentence[i])
        sentence[i] = sentence[i].lower()
        
#         if sentence[i] in stop_words and sentence[i] not in ['who', 'what', 'when', 'where', 'why', 'how']:
#             sentence[i] = ""
        if sentence[i].isnumeric():
            sentence[i] = "numericnumber"
        elif utils.is_spelled_out_number(sentence[i]):
            sentence[i] = "nonnumericnumber"
        elif utils.is_TA_or_instructor_name(sentence[i]):
            sentence[i] = "name"
        elif utils.is_error_code(sentence[i]):
            sentence[i] = "errorcode"
        elif utils.is_filename(sentence[i]):
            sentence[i] = "filename"
        elif utils.is_system_word(sentence[i]):
            sentence[i] = "sys"
        elif utils.is_function(sentence[i]):
            sentence[i] = "func"

    return ' '.join(sentence)

# %%
for i in range(len(answerable_data)):
    print(answerable_data[:,0][i])
    print(answerable_preprocessor(answerable_data[:,0][i]))
    print()
# Out:
# I fail my single character test for mystring, and I'm not sure why
# i fail my single character test for mystring , and im not sure why
#
# phase 3 -> I have the machine code and the ascii representation of my cookie but i'm not sure where to place the ascii cookie string
# phase numericnumber - > i have the machine code and the ascii representation of my cookie but im not sure where to place the ascii cookie string
#
# How do I run the bounce simulation or test my files now that gravity.c has been introduced to the code?
# how do i run the bounce simulation or test my files now that filename has been introduced to the code ?
#
# how to use get
# how to use get
#
# I need help with debugging my c tests
# i need help with debugging my c tests
#
# values and keyset for chaining dictionary
# values and keyset for chaining dictionary
#
# lmao help please sanity test is testing my sanity
#
# lmao help please sanity test is testing my sanity
#
# How should I forward struct declaration in vector.c?
# how should i forward struct declaration in filename ?
#
# have moving function but paceman does not move
# have moving function but paceman does not move
#
# How many policies can we implement?
# how many policies can we implement ?
#
# Where do I store branch_address?
# where do i store camelsnakecase ?
#
# I need help debugging the AIHangman for the A tests.
# i need help debugging the camelsnakecase for the a tests .
#
# I would like to hack countable thoughts.
# i would like to hack countable thoughts .
#
# getScore is extremely confusing. Where is the cipher object I use? How do I use likelihoods?
# camelsnakecase is extremely confusing . where is the cipher object i use ? how do i use likelihoods ?
#
# I have some errors with mm_checkheap. I think my implementation is almost correct, so fixing this would help a lot.
# i have some errors with camelsnakecase . i think my implementation is almost correct , so fixing this would help a lot .
#
# why do we need a counter for the conditionals?
#
# why do we need a counter for the conditionals ?
#
# Project 4 part D complete method
# project numericnumber part d complete method
#
# NGram tests are not going well
# camelsnakecase tests are not going well
#
# Sorry for last minute question! I'm trying to understand tries, starting to implement TreeMap
# sorry for last minute question ! im trying to understand tries , starting to implement camelsnakecase
#
# My project 0 code compiles without error, but fails all of the tests. I do not see what is wrong with it.
# my project numericnumber code compiles without error , but fails all of the tests . i do not see what is wrong with it .
#
# Remove doesn't work and we can't figure out why.
# remove doesnt work and we cant figure out why .
#
# How to get and store variables in the stack. Aka how to access it. Do I use push and pop?
# how to get and store variables in the stack . aka how to access it . do i use push and pop ?
#
# using reader writer locks vs normal locks and testing
# using reader writer locks vs normal locks and testing
#
# how to compile because make is not working
# how to compile because make is not working
#
# I don't understand why sometimes my code thinks it is a better option to add a letter.
# i dont understand why sometimes my code thinks it is a better option to add a letter .
#
# For the incomplete definition of type struct vector error, this wasn't an issue in lab 1; I'm guessing this is because the definition of the struct was given in the header file instead of the .c file, and the test file could access it. Is one way better than the other? Or is it something like making fields public/private in Java?
# for the incomplete definition of type struct vector error , this wasnt an issue in lab numericnumber ; im guessing this is because the definition of the struct was given in the header file instead of the filename file , and the test file could access it . is nonnumericnumber way better than the other ? or is it something like making fields public private in java ?
#
# Issues with the stress tests and other issues with the topK
# issues with the stress tests and other issues with the topk
#
# I don't understand TopKSort. I also have some questions about the prewritten stuff for NGramMap
# i dont understand camelsnakecase . i also have some questions about the prewritten stuff for camelsnakecase
#
# Most of my A tests are passing, but I'm not passing the tic() tests.
# most of my a tests are passing , but im not passing the tic ( ) tests .
#
# debugging weird bug + looking over remove
# debugging weird bug + looking over remove
#
# C tests help with the percolate down
# c tests help with the percolate down
#
# I need help debugging the C Tests and ensuring all methods are implemented properly
#
# i need help debugging the c tests and ensuring all methods are implemented properly
#
# I have a question about the MinFourHeap portion of the project.
# i have a question about the camelsnakecase portion of the project .
#
# seg fault occurs after optimization code added
# errorcode fault occurs after optimization code added
#
# How do I run the testing script on wc.c and can I get general quick feedback on my code for wc.c? Not quite sure what is being looked for during code review.
# how do i run the testing script on filename and can i get general quick feedback on my code for filename ? not quite sure what is being looked for during code review .
#
# Having trouble finding a memory leak in bounce
# having trouble finding a memory leak in bounce
#
# I'm having trouble understanding the project
#
#
# im having trouble understanding the project
#
# Questions about how to make our program and the tests code use a page replacement policy we will implement.
# questions about how to make our program and the tests code use a page replacement policy we will implement .
#
# I'm trying to calculate the capacity of vec_list instead of coding it in, but when I try to take sizeof(list->array), it just gives me 8 no matter what the initial size was. What is the correct way to calculate the capacity here? I'm allocating memory using list->array = malloc(initial_size * sizeof(vector_t*));
# im trying to calculate the capacity of camelsnakecase instead of coding it in , but when i try to take sizeof ( list- > array ) , it just gives me numericnumber no matter what the initial size was . what is the correct way to calculate the capacity here ? im allocating memory using list- > array = malloc ( camelsnakecase * sizeof ( camelsnakecase ) ) ;
#
# Can't get remove to work. I'm using a stack to track alphabets and nodes I've already traversed. Want to see if it works.
#
# Also, I don't think I understand the B tests conceptually at all
#
# cant get remove to work . im using a stack to track alphabets and nodes ive already traversed . want to see if it works . also , i dont think i understand the b tests conceptually at all
#
# doesn't let me use key.length() or node.size() to get the length of the key
# doesnt let me use key.length ( ) or node.size ( ) to get the length of the key
#
# I don't know how to initialize arrays in java.
# i dont know how to initialize arrays in java .
#
# Hi. I would like to go over my approach for mark and sweep :)
# hi . i would like to go over my approach for mark and sweep : )
#
# how do I generate random numbers without using random class
# how do i generate random numbers without using random class
#
# How does one change the privilege ring?
# how does nonnumericnumber change the privilege ring ?
#
# intellij hangs indefinitely when running tests instead of failing normally
# sys hangs indefinitely when running tests instead of failing normally
#
# having trouble understanding the method
# having trouble understanding the method
#
# D Tests, failing one movie
# d tests , failing nonnumericnumber movie
#
# my part 3 code prints all the correct numbers except two - not sure of the source
# my part numericnumber code prints all the correct numbers except nonnumericnumber - not sure of the source
#
# Unsure where to start for evil code, specifically the splitting of the pattern things
# unsure where to start for evil code , specifically the splitting of the pattern things
#
# shouldn't be returning null
#
# shouldnt be returning null
#
# I'm still stuck on how to approach getSolution :(
# im still stuck on how to approach camelsnakecase : (
#
# Working on phase 2/3 of question 2
# working on phase 2 3 of question numericnumber
#
# Failing put, remove, containsKey, size in MoveToFrontDictionary
# failing put , remove , camelsnakecase , size in camelsnakecase
#
# I'm trying to alphabetically order values, but can't figure out how to lexicographically prioritize a dash over a letter value.
# im trying to alphabetically order values , but cant figure out how to lexicographically prioritize a dash over a letter value .
#
# My test6 prints the expected list but shifted a bit, and the first numbers are also different.
# my test6 prints the expected list but shifted a bit , and the first numbers are also different .
#
# why do we have to return something in remove but not in add methods?
# what exactly does E in the code mean?
# why are enqueue and push boolean but sequeue and pop E?
# why do we have to return something in remove but not in add methods ? what exactly does e in the code mean ? why are enqueue and push boolean but sequeue and pop e ?
#
# question about polygon.c's translate function. How do we mutate the original polygon if we aren't able to access the data fields of the vec_list? We can't remove or add at specific indices, and I can only think of creating a new vec_list that copies the contents of the original one but that's not mutating the original polygon.
# question about filename translate function . how do we mutate the original polygon if we arent able to access the data fields of the camelsnakecase ? we cant remove or add at specific indices , and i can only think of creating a new camelsnakecase that copies the contents of the original nonnumericnumber but thats not mutating the original polygon .
#
# Core dump I don't understand in extend heap
# core dump i dont understand in extend heap
#
# I don't exactly know how to implement TrieMap iterator
# i dont exactly know how to implement camelsnakecase iterator
#
# I'm editing wc.c. When I enter "atom wc.c" in the terminal it just stares at me. I selected start server on startup and was having success earlier, so I don't know what is failing now.
# im editing filename . when i enter atom filename in the terminal it just stares at me . i selected start sys on startup and was having success earlier , so i dont know what is failing now .
#
# question about my understanding of the heap
# question about my understanding of the heap
#
# Why does the first block go at mem_heap_lo() + 8?
# why does the first block go at camelsnakecase ( ) + numericnumber ?
#
# We are getting errors with bounce
# we are getting errors with bounce
#
# i redid my toString function and it's working less now.
# i redid my camelsnakecase function and its working less now .
#
# Our test_suite_vector.c is having some issues although we don't know why list.c would affect it.  We get the error message:
#
# make: *** No rule to make target 'out/vec_list.o', needed by 'bin/test_suite_vector'.  Stop.
#
# our camelsnakecase is having some issues although we dont know why filename would affect it . we get the error message : make : *** no rule to make target out/vec_list.o , needed by bin test_suite_vector . stop .
#
# move to front dictionary put/get/remove
# move to front dictionary put get remove
#
# I tried to change vec_list_init to not have an initial size argument, and then resize it when a new vector is added, but I believe that the add function is throwing an error when the program is actually run
#
# i tried to change camelsnakecase to not have an initial size argument , and then resize it when a new vector is added , but i believe that the add function is throwing an error when the program is actually run
#
# add front is being weird and im not sure why.
# add front is being weird and im not sure why .
#
# I keep timing out. Especially when I pass it to Git. I don't know how to make my code more efficient
# i keep timing out . especially when i pass it to sys . i dont know how to make my code more efficient
#
# Am i supposed to have  main in bounce.c
#
# am i supposed to have main in filename
#
# I dont really get the offset part of explicit lists
# i dont really get the offset part of explicit lists
#
# cant pass test test idk why
# cant pass test test idk why
#
# More error messages from mystring.c
# more error messages from filename
#
# For assignment 3, how do I write a case that can take in i_iconst* (instead of having to explicitly write out i_iconst_[m1, 0, ..., 5])?
# for assignment numericnumber , how do i write a case that can take in camelsnakecase ( instead of having to explicitly write out camelsnakecase [ m1 , numericnumber , ... , numericnumber ] ) ?
#
# Having trouble committing to gitlab
# having trouble committing to sys
#
# I'm testing vector and I'm still not comfortable with c and working from the terminal
# im testing vector and im still not comfortable with c and working from the terminal
#
# I am getting an UnsupportedOperationException error.
# i am getting an errorcode error .
#
# Problem with getting rsp location.
# problem with getting rsp location .
#
# How to run SubstitutionSolver with message already decrypted...
# how to run camelsnakecase with message already decrypted ...
#
# I am getting an UnsupportedOperationException error in my randomSwap method and I'm trying to figure out what that means
# i am getting an errorcode error in my camelsnakecase method and im trying to figure out what that means
#
# Git commands to move files from project 1 to project 2?
# sys commands to move files from project numericnumber to project numericnumber ?
#
# Should the guitar string class extend CircularArrayFixedSizeQueue?
# should the guitar string class extend camelsnakecase ?
#
# Don't think my array storing my values is getting properly initialized, all values always null
#
# dont think my array storing my values is getting properly initialized , all values always null
#
# question about infinite list and buffer overflow
# question about infinite list and buffer errorcode
#
# We are working on implementing .*, the last part of the lab, and we are confused. We think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works. Can you help?
# we are working on implementing . * , the last part of the lab , and we are confused . we think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works . can you help ?
#
# Semaphore questions : freeing? implementation correctness
# semaphore questions : freeing ? implementation correctness
#
# Hey how do I update mu git so that im up to date with mu partner?
# Also how do we populate titles with trie?
#
# hey how do i update mu sys so that im up to date with mu partner ? also how do we populate titles with trie ?
#
# I created some tests in my Main for addFront/addBack and they work as expected when I add a small number of elements, but they are not passing the LinkedDeque tests.
#
# My removeBack is not working and not sure why, currently debugging.
# i created some tests in my main for camelsnakecase and they work as expected when i add a small number of elements , but they are not passing the camelsnakecase tests . my camelsnakecase is not working and not sure why , currently debugging .
#
# We're having trouble making a new ssh key in the VM.
# were having trouble making a new sys key in the sys .
#
# Debugging implicit free list. (I vaguely know how to use GDB, but I don't understand seg fault I'm getting)
# debugging implicit free list . ( i vaguely know how to use gdb , but i dont understand errorcode fault im getting )
#
# Clarification of conceptual questions
# clarification of conceptual questions
#
# I'm not sure what the supplier does.
# im not sure what the supplier does .
#
# How do I inject code into the program?
# how do i inject code into the program ?
#
# B tests are running correctly except for a single movie title. I have spent several hours debugging this one problem.
#
# b tests are running correctly except for a single movie title . i have spent several hours debugging this nonnumericnumber problem .
#
# segmentation fault; created a new class , bouncer, to hold vertices, color, and velocity but segmentation fault when trying to access teh vertices pointer
#
# errorcode fault ; created a new class , bouncer , to hold vertices , color , and velocity but errorcode fault when trying to access teh vertices pointer
#
# Can't run Makefile because can't locate test_util, but it exists
#
# cant run sys because cant locate camelsnakecase , but it exists
#
# How do I do things
#
#
#
#
#
# regarding stack
# how do i do things regarding stack
#
# when passing an array through a function, do we not need to int *array[]? is the array that is modified in the function the array itself or a copy of it?
# when passing an array through a function , do we not need to int *array [ ] ? is the array that is modified in the function the array itself or a copy of it ?
#
# Confused over keySet, values, and Iterator uses and implementations.
# confused over camelsnakecase , values , and iterator uses and implementations .
#
# Should we have a vec_init function in our vector.c? I don't see it in the header file and am a little confused about how to declare/make a new vector
# should we have a camelsnakecase function in our filename ? i dont see it in the header file and am a little confused about how to declare make a new vector
#
# We are debugging the polygo_rotate function
# we are debugging the camelsnakecase function
#
# I'm on task 3 and want to make sure my logic is right
# im on task numericnumber and want to make sure my logic is right
#
# I want to confirm that my logic for the vec_list_remove function is correct. I'm currently not freeing any memory or removing anything from the list, other than decreasing the size, and I'm not sure that's correct. Also, my malloc-ing seems to work, but I want to ask if my logic is correct. I also want to ask if my method for changing the vectors in the polygon is valid
# i want to confirm that my logic for the camelsnakecase function is correct . im currently not freeing any memory or removing anything from the list , other than decreasing the size , and im not sure thats correct . also , my malloc-ing seems to work , but i want to ask if my logic is correct . i also want to ask if my method for changing the vectors in the polygon is valid
#
# what is ArrayDeque() ;; is it a method? and how do I set up the initial capacity?
# what is camelsnakecase ( ) ; ; is it a method ? and how do i set up the initial capacity ?
#
# getCompletions method is not working right now
#
# camelsnakecase method is not working right now
#
# Wanted to talk over out idea of how to make several vec_lists
# wanted to talk over out idea of how to make several camelsnakecase
#
# small questions/just wanted to kind of talk about my ideas for some implementations in proj 2 with a TA
# small questions just wanted to kind of talk about my ideas for some implementations in proj numericnumber with a ta
#
# regarding math.s and algorithm for gcd
# regarding math.s and algorithm for gcd
#
# number of lines wc.c part
# tests give an error "no new line at end of file"
# number of lines filename part tests give an error no new line at end of file
#
# how to implement the get method
# how to implement the get method
#
# I don't exactly know how to set up the constructor for the guitar string
# i dont exactly know how to set up the constructor for the guitar string
#
# VM doesn't work. Cannot git clone.
# sys doesnt work . can not sys clone .
#
# Hi, we are having some issues with making the keys
# hi , we are having some issues with making the keys
#
# debugging segfault in __sthread_initialize_context
# debugging errorcode in camelsnakecase
#
# I think I know how to do phase 4 conceptually with the recursive function but I have no clue how to follow the code and honestly I've done so many things at this point
# i think i know how to do phase numericnumber conceptually with the recursive function but i have no clue how to follow the code and honestly ive done so many things at this nonnumericnumber
#
# Remove method does not work properly.
# remove method does not work properly .
#
# something is rotten in the B test (timeout errors)
# something is rotten in the b test ( errorcode errors )
#
# Question about using array to back heap
# question about using array to back heap
#
# Project 5, on extension. Pretty sure I'm on the wrong track implementing MoveToFrontDictionary.
# project numericnumber , on extension . pretty sure im on the wrong track implementing camelsnakecase .
#
# we don't understand how to start
# we dont understand how to start
#
# cant find SDL2/SDL2_gfxPrimitives.h "Clang not found"
# cant find camelsnakecase clang not found
#
# how do I run a test individually?
# how do i run a test individually ?
#
# What are the integer register files?
# what are the integer register files ?
#
# We have a question about how to implement the gerrymandering portion of the lab.
# we have a question about how to implement the gerrymandering portion of the lab .
#
# How would I get the private variables from outside a class?
# how would i get the private variables from outside a class ?
#
# Not letting me access struct. Should I modify the mm.h?
# not letting me access struct . should i modify the filename ?
#
# Need help explaining plateaus in iter for linked list
# need help explaining plateaus in iter for linked list
#
# How can I save the  array made in the constructor of guitar without using a variable?
# how can i save the array made in the constructor of guitar without using a variable ?
#
# I'm confused on how the resizing for ChainingHash is supposed to work. Like in the put method, do we have to calculate the load and compare with the load factor?
# im confused on how the resizing for camelsnakecase is supposed to work . like in the put method , do we have to calculate the load and compare with the load factor ?
#
# Having trouble with debugging graph
# having trouble with debugging graph
#
# Want to make sure tier plot is correct. Confused by why it is like this.
# want to make sure tier plot is correct . confused by why it is like this .
#
# Confused about structure of BeaverGraphsMap
# confused about structure of camelsnakecase
#
# I need a lot of help.  Also I waited for an hour to get down to nobody left in the queue just to see it at 0 people for 15 minutes.  Nobody contacted me, the page refreshed, and now there are 5 people in front of me.  I really need help on this and
#
# i need a lot of help . also i waited for an hour to get down to nobody left in the queue just to see it at numericnumber people for numericnumber minutes . nobody contacted me , the page refreshed , and now there are numericnumber people in front of me . i really need help on this and
#
# how to run assembly code
#
# how to run assembly code
#
# How to add to an array and deal with leading and trailing spaces.
# how to add to an array and deal with leading and trailing spaces .
#
# We are working on implementing .*, the last part of the lab, and we are confused. We think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works. We are lab03-sandslash if you want to look at our git code
# we are working on implementing . * , the last part of the lab , and we are confused . we think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works . we are lab03-sandslash if you want to look at our sys code
#
# Trying to debug LinkedDeque; says error is in peakFront but I can't see whats wrong
# trying to debug camelsnakecase ; says error is in camelsnakecase but i cant see whats wrong
#
# how to make a linked deque
# how to make a linked deque
#
# Question about remove method implementation
# question about remove method implementation
#
# Having trouble with assigning values to rdi
# having trouble with assigning values to rdi
#
# do we need to flush the cache because of calloc?
# do we need to flush the cache because of calloc ?
#
# I'm having trouble figuring out why my longest.c doesn't output anything. I've been putting print statements throughout to see what points it's reaching, but still unsure what the problem is.
# im having trouble figuring out why my filename doesnt output anything . ive been putting print statements throughout to see what points its reaching , but still unsure what the problem is .
#
# Understanding task 3/debugging what i have
# understanding task 3 debugging what i have
#
# I cant figure out where to start debugging my C tests.
# i cant figure out where to start debugging my c tests .
#
# b test not passing bc of bug and long loop??
#
# b test not passing bc of bug and long loop ? ?
#
# Confused about different data structures
# confused about different data structures
#
# The shape doesn't bounce, just disappears
# the shape doesnt bounce , just disappears
#
# I don't know how to write the resize function such that memory is not leaked. I've tried creating a copy of the current list to draw from after reallocating memory for list->data, as well as just pointing list->data at a new, larger array, but both methods cause memory leaks.
# i dont know how to write the resize function such that memory is not leaked . ive tried creating a copy of the current list to draw from after reallocating memory for list- > data , as well as just pointing list- > data at a new , larger array , but both methods cause memory leaks .
#
# test8 still giving memory error
# test8 still giving memory error
#
# I don't understand how to implement the chaining hash dictionary
# i dont understand how to implement the chaining hash dictionary
#
# Something is weird with timeouts and we're not sure why
# something is weird with errorcode and were not sure why
#
# How do I test my code using the fib files
#
#
#
# how do i test my code using the fib files

# %%
pipeline = Pipeline([
    ('features', FeatureUnion([
        ('vectorizer', CountVectorizer(preprocessor=answerable_preprocessor)),
        ('char_count', WordCountTransformer())
    ])),
    ('clf', RandomForestClassifier())
])

pipeline.fit(answerable_data[:,0], answerable_data[:,1])
np.mean(cross_val_score(pipeline, answerable_data[:,0], answerable_data[:,1]))
# Out:
# 0.6529032258064517

# %%
pipeline = Pipeline([
    ('features', FeatureUnion([
        ('ngram', CountVectorizer(preprocessor=None)),
        ('tfidf', TfidfTransformer()),
        ('word_count', WordCountTransformer()),
        ('char_count', CharacterCountTransformer())
    ])),
    ('clf', RandomForestClassifier())
])

pipeline.fit(answerable_data[:,0], answerable_data[:,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ab97097f2005> in <module>
#       8 ])
#       9
# ---> 10 pipeline.fit(answerable_data[:,0], answerable_data[:,1])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     934             sum of n_components (output dimension) over transformers.
#     935         """
# --> 936         results = self._parallel_func(X, y, fit_params, _fit_transform_one)
#     937         if not results:
#     938             # All transformers are None
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _parallel_func(self, X, y, fit_params, func)
#     964             message=self._log_message(name, idx, len(transformers)),
#     965             **fit_params) for idx, (name, transformer,
# --> 966                                     weight) in enumerate(transformers, 1))
#     967
#     968     def transform(self, X):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit(self, X, y)
#    1448             a matrix of term/token counts
#    1449         """
# -> 1450         X = check_array(X, accept_sparse=('csr', 'csc'))
#    1451         if not sp.issparse(X):
#    1452             X = sp.csr_matrix(X)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=["I fail my single character test for mystring, and I'm not sure why"
#  "phase 3 -> I have the machine code and the ascii representation of my cookie but i'm not sure where to place the ascii cookie string"
#  'How do I run the bounce simulation or test my files now that gravity.c has been introduced to the code? '
#  'how to use get' 'I need help with debugging my c tests'
#  'values and keyset for chaining dictionary'
#  'lmao help please sanity test is testing my sanity\n'
#  'How should I forward struct declaration in vector.c?'
#  'have moving function but paceman does not move '
#  'How many policies can we implement? ' 'Where do I store branch_address?'
#  'I need help debugging the AIHangman for the A tests.'
#  'I would like to hack countable thoughts. '
#  'getScore is extremely confusing. Where is the cipher object I use? How do I use likelihoods?'
#  'I have some errors with mm_checkheap. I think my implementation is almost correct, so fixing this would help a lot.'
#  'why do we need a counter for the conditionals?\n'
#  'Project 4 part D complete method' 'NGram tests are not going well'
#  "Sorry for last minute question! I'm trying to understand tries, starting to implement TreeMap"
#  'My project 0 code compiles without error, but fails all of the tests. I do not see what is wrong with it.'
#  "Remove doesn't work and we can't figure out why."
#  'How to get and store variables in the stack. Aka how to access it. Do I use push and pop?'
#  'using reader writer locks vs normal locks and testing'
#  'how to compile because make is not working'
#  "I don't understand why sometimes my code thinks it is a better option to add a letter. "
#  "For the incomplete definition of type struct vector error, this wasn't an issue in lab 1; I'm guessing this is because the definition of the struct was given in the header file instead of the .c file, and the test file could access it. Is one way better than the other? Or is it something like making fields public/private in Java? "
#  'Issues with the stress tests and other issues with the topK'
#  "I don't understand TopKSort. I also have some questions about the prewritten stuff for NGramMap"
#  "Most of my A tests are passing, but I'm not passing the tic() tests."
#  'debugging weird bug + looking over remove'
#  'C tests help with the percolate down'
#  'I need help debugging the C Tests and ensuring all methods are implemented properly\n'
#  'I have a question about the MinFourHeap portion of the project.'
#  'seg fault occurs after optimization code added'
#  'How do I run the testing script on wc.c and can I get general quick feedback on my code for wc.c? Not quite sure what is being looked for during code review.  '
#  'Having trouble finding a memory leak in bounce'
#  "I'm having trouble understanding the project\n\n"
#  'Questions about how to make our program and the tests code use a page replacement policy we will implement.'
#  "I'm trying to calculate the capacity of vec_list instead of coding it in, but when I try to take sizeof(list->array), it just gives me 8 no matter what the initial size was. What is the correct way to calculate the capacity here? I'm allocating memory using list->array = malloc(initial_size * sizeof(vector_t*));"
#  "Can't get remove to work. I'm using a stack to track alphabets and nodes I've already traversed. Want to see if it works.\n\nAlso, I don't think I understand the B tests conceptually at all\n"
#  "doesn't let me use key.length() or node.size() to get the length of the key"
#  "I don't know how to initialize arrays in java."
#  'Hi. I would like to go over my approach for mark and sweep :) '
#  'how do I generate random numbers without using random class'
#  'How does one change the privilege ring?'
#  'intellij hangs indefinitely when running tests instead of failing normally'
#  'having trouble understanding the method' 'D Tests, failing one movie'
#  'my part 3 code prints all the correct numbers except two - not sure of the source'
#  'Unsure where to start for evil code, specifically the splitting of the pattern things'
#  "shouldn't be returning null\n"
#  "I'm still stuck on how to approach getSolution :( "
#  'Working on phase 2/3 of question 2'
#  'Failing put, remove, containsKey, size in MoveToFrontDictionary'
#  "I'm trying to alphabetically order values, but can't figure out how to lexicographically prioritize a dash over a letter value."
#  'My test6 prints the expected list but shifted a bit, and the first numbers are also different.'
#  'why do we have to return something in remove but not in add methods?\nwhat exactly does E in the code mean?\nwhy are enqueue and push boolean but sequeue and pop E?'
#  "question about polygon.c's translate function. How do we mutate the original polygon if we aren't able to access the data fields of the vec_list? We can't remove or add at specific indices, and I can only think of creating a new vec_list that copies the contents of the original one but that's not mutating the original polygon."
#  "Core dump I don't understand in extend heap"
#  "I don't exactly know how to implement TrieMap iterator"
#  'I\'m editing wc.c. When I enter "atom wc.c" in the terminal it just stares at me. I selected start server on startup and was having success earlier, so I don\'t know what is failing now.'
#  'question about my understanding of the heap'
#  'Why does the first block go at mem_heap_lo() + 8?'
#  'We are getting errors with bounce'
#  "i redid my toString function and it's working less now."
#  "Our test_suite_vector.c is having some issues although we don't know why list.c would affect it.  We get the error message:\n\nmake: *** No rule to make target 'out/vec_list.o', needed by 'bin/test_suite_vector'.  Stop.\n"
#  'move to front dictionary put/get/remove'
#  'I tried to change vec_list_init to not have an initial size argument, and then resize it when a new vector is added, but I believe that the add function is throwing an error when the program is actually run\n'
#  'add front is being weird and im not sure why.'
#  "I keep timing out. Especially when I pass it to Git. I don't know how to make my code more efficient"
#  'Am i supposed to have  main in bounce.c\n'
#  'I dont really get the offset part of explicit lists'
#  'cant pass test test idk why ' 'More error messages from mystring.c'
#  'For assignment 3, how do I write a case that can take in i_iconst* (instead of having to explicitly write out i_iconst_[m1, 0, ..., 5])?'
#  'Having trouble committing to gitlab'
#  "I'm testing vector and I'm still not comfortable with c and working from the terminal"
#  'I am getting an UnsupportedOperationException error. '
#  'Problem with getting rsp location.'
#  'How to run SubstitutionSolver with message already decrypted...'
#  "I am getting an UnsupportedOperationException error in my randomSwap method and I'm trying to figure out what that means "
#  'Git commands to move files from project 1 to project 2?'
#  'Should the guitar string class extend CircularArrayFixedSizeQueue?'
#  "Don't think my array storing my values is getting properly initialized, all values always null\n"
#  'question about infinite list and buffer overflow'
#  'We are working on implementing .*, the last part of the lab, and we are confused. We think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works. Can you help? '
#  'Semaphore questions : freeing? implementation correctness'
#  'Hey how do I update mu git so that im up to date with mu partner?\nAlso how do we populate titles with trie?\n'
#  'I created some tests in my Main for addFront/addBack and they work as expected when I add a small number of elements, but they are not passing the LinkedDeque tests.\n\nMy removeBack is not working and not sure why, currently debugging. '
#  "We're having trouble making a new ssh key in the VM."
#  "Debugging implicit free list. (I vaguely know how to use GDB, but I don't understand seg fault I'm getting)"
#  'Clarification of conceptual questions'
#  "I'm not sure what the supplier does.  "
#  'How do I inject code into the program?'
#  'B tests are running correctly except for a single movie title. I have spent several hours debugging this one problem.                                                                     \n'
#  'segmentation fault; created a new class , bouncer, to hold vertices, color, and velocity but segmentation fault when trying to access teh vertices pointer\n'
#  "Can't run Makefile because can't locate test_util, but it exists\n"
#  'How do I do things\n\n\n\n\n\nregarding stack'
#  'when passing an array through a function, do we not need to int *array[]? is the array that is modified in the function the array itself or a copy of it?'
#  'Confused over keySet, values, and Iterator uses and implementations.'
#  "Should we have a vec_init function in our vector.c? I don't see it in the header file and am a little confused about how to declare/make a new vector"
#  'We are debugging the polygo_rotate function'
#  "I'm on task 3 and want to make sure my logic is right"
#  "I want to confirm that my logic for the vec_list_remove function is correct. I'm currently not freeing any memory or removing anything from the list, other than decreasing the size, and I'm not sure that's correct. Also, my malloc-ing seems to work, but I want to ask if my logic is correct. I also want to ask if my method for changing the vectors in the polygon is valid"
#  'what is ArrayDeque() ;; is it a method? and how do I set up the initial capacity?'
#  'getCompletions method is not working right now \n'
#  'Wanted to talk over out idea of how to make several vec_lists'
#  'small questions/just wanted to kind of talk about my ideas for some implementations in proj 2 with a TA '
#  'regarding math.s and algorithm for gcd'
#  'number of lines wc.c part\ntests give an error "no new line at end of file"'
#  'how to implement the get method'
#  "I don't exactly know how to set up the constructor for the guitar string"
#  "VM doesn't work. Cannot git clone."
#  'Hi, we are having some issues with making the keys '
#  'debugging segfault in __sthread_initialize_context'
#  "I think I know how to do phase 4 conceptually with the recursive function but I have no clue how to follow the code and honestly I've done so many things at this point "
#  'Remove method does not work properly. '
#  'something is rotten in the B test (timeout errors)'
#  'Question about using array to back heap'
#  "Project 5, on extension. Pretty sure I'm on the wrong track implementing MoveToFrontDictionary."
#  "we don't understand how to start"
#  'cant find SDL2/SDL2_gfxPrimitives.h "Clang not found"'
#  'how do I run a test individually?'
#  'What are the integer register files?'
#  'We have a question about how to implement the gerrymandering portion of the lab.'
#  'How would I get the private variables from outside a class?'
#  'Not letting me access struct. Should I modify the mm.h?'
#  'Need help explaining plateaus in iter for linked list'
#  'How can I save the  array made in the constructor of guitar without using a variable?'
#  "I'm confused on how the resizing for ChainingHash is supposed to work. Like in the put method, do we have to calculate the load and compare with the load factor? "
#  'Having trouble with debugging graph'
#  'Want to make sure tier plot is correct. Confused by why it is like this.'
#  'Confused about structure of BeaverGraphsMap'
#  'I need a lot of help.  Also I waited for an hour to get down to nobody left in the queue just to see it at 0 people for 15 minutes.  Nobody contacted me, the page refreshed, and now there are 5 people in front of me.  I really need help on this and \n'
#  'how to run assembly code\n'
#  'How to add to an array and deal with leading and trailing spaces.'
#  'We are working on implementing .*, the last part of the lab, and we are confused. We think our code for * may be slightly wrong because we have had to edit things and in the project spec it says it should already work if * works. We are lab03-sandslash if you want to look at our git code'
#  "Trying to debug LinkedDeque; says error is in peakFront but I can't see whats wrong"
#  'how to make a linked deque'
#  'Question about remove method implementation'
#  'Having trouble with assigning values to rdi'
#  'do we need to flush the cache because of calloc?'
#  "I'm having trouble figuring out why my longest.c doesn't output anything. I've been putting print statements throughout to see what points it's reaching, but still unsure what the problem is. "
#  'Understanding task 3/debugging what i have'
#  'I cant figure out where to start debugging my C tests.'
#  'b test not passing bc of bug and long loop??\n'
#  'Confused about different data structures'
#  "The shape doesn't bounce, just disappears"
#  "I don't know how to write the resize function such that memory is not leaked. I've tried creating a copy of the current list to draw from after reallocating memory for list->data, as well as just pointing list->data at a new, larger array, but both methods cause memory leaks. "
#  'test8 still giving memory error'
#  "I don't understand how to implement the chaining hash dictionary"
#  "Something is weird with timeouts and we're not sure why"
#  'How do I test my code using the fib files \n\n\n'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
def answerable_preprocessor(sentence):
    sentence = utils.check_quotations(sentence)
    sentence = word_tokenize(sentence)
    
    for i in range(len(sentence)):
        sentence[i] = utils.check_camel_snakecase(sentence[i])
        sentence[i] = sentence[i].lower()
        
#         if sentence[i] in stop_words and sentence[i] not in ['who', 'what', 'when', 'where', 'why', 'how']:
#             sentence[i] = ""
        elif sentence[i].isnumeric():
            sentence[i] = "numericnumber"
        elif utils.is_spelled_out_number(sentence[i]):
            sentence[i] = "nonnumericnumber"
        elif utils.is_TA_or_instructor_name(sentence[i]):
            sentence[i] = "name"
        elif utils.is_error_code(sentence[i]):
            sentence[i] = "errorcode"
        elif utils.is_system_word(sentence[i]):
            sentence[i] = "sys"
        elif utils.is_function(sentence[i]):
            sentence[i] = "func"

    return ' '.join(sentence)

# %%
pipeline = Pipeline([
    ('features', FeatureUnion([
        ('ngram', CountVectorizer(preprocessor=None)),
        ('tfidf', TfidfTransformer()),
        ('word_count', WordCountTransformer()),
        ('char_count', CharacterCountTransformer())
    ])),
    ('clf', None)
])

# %%
param_grid = [
    {
        'features__ngram__ngram_range': [(1,1), (1,2), (1,3)],
        'features__ngram__max_features': [None, 100, 250, 500, 1000, 1500, 2000, 2500, 3000],
        'features__tfidf': [TfidfTransformer(), 'drop'],
        'clf': [RandomForestClassifier()],
        'clf__n_estimators': [100, 250, 500, 750, 1000],
        'clf__max_features': ['auto', 'log2'],
        'clf__max_depth': [None, 100, 500, 1000],
        'clf__min_samples_split': [2, 5, 10, 12],
        'clf__min_samples_leaf': [1, 2, 4, 8],
        'clf__criterion': ['gini', 'entropy'],
#         'clf__bootstrap': [True, False],
#         'clf__C': [.01, .1, 1, 10, 100],
        'clf__class_weight': [None, 'balanced']
    }, {
        'features__ngram__ngram_range': [(1,1), (1,2), (1,3)],
        'features__ngram__max_features': [None, 100, 250, 500, 1000, 1500, 2000, 2500, 3000],
        'features__tfidf': [TfidfTransformer(), 'drop'],
        'clf': [MultinomialNB()],
        'clf__alpha': [1, .1, .01, .001] 
    }]

search = RandomizedSearchCV(pipeline, param_grid, n_jobs=-1, scoring='accuracy', n_iter=100)
# search = RandomizedSearchCV(pipeline, param_grid, n_jobs=-1, n_iter=100)
search.fit(answerable_data[:,0], answerable_data[:,1])
# Out:
# RandomizedSearchCV(cv=None, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('features',
#                                               FeatureUnion(n_jobs=None,
#                                                            transformer_list=[('ngram',
#                                                                               CountVectorizer(analyzer='word',
#                                                                                               binary=False,
#                                                                                               decode_error='strict',
#                                                                                               dtype=<class 'numpy.int64'>,
#                                                                                               encoding='utf-8',
#                                                                                               input='content',
#                                                                                               lowercase=True,
#                                                                                               max_df=1.0,
#                                                                                               max_features=None,
#                                                                                               min_df=1,
#                                                                                               ngram_range=(1,
#                                                                                                            1),
#                                                                                               preproc...
#                                          'clf__alpha': [1, 0.1, 0.01, 0.001],
#                                          'features__ngram__max_features': [None,
#                                                                            100,
#                                                                            250,
#                                                                            500,
#                                                                            1000,
#                                                                            1500,
#                                                                            2000,
#                                                                            2500,
#                                                                            3000],
#                                          'features__ngram__ngram_range': [(1,
#                                                                            1),
#                                                                           (1,
#                                                                            2),
#                                                                           (1,
#                                                                            3)],
#                                          'features__tfidf': [TfidfTransformer(norm='l2',
#                                                                               smooth_idf=True,
#                                                                               sublinear_tf=False,
#                                                                               use_idf=True),
#                                                              'drop']}],
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %%
np.mean(cross_val_score(search.best_estimator_, answerable_data[:,0], answerable_data[:,1]))
# Out:
# 0.6270967741935484

# %%
search.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('ngram',
#                                                  CountVectorizer(analyzer='word',
#                                                                  binary=False,
#                                                                  decode_error='strict',
#                                                                  dtype=<class 'numpy.int64'>,
#                                                                  encoding='utf-8',
#                                                                  input='content',
#                                                                  lowercase=True,
#                                                                  max_df=1.0,
#                                                                  max_features=1500,
#                                                                  min_df=1,
#                                                                  ngram_range=(1,
#                                                                               2),
#                                                                  preprocessor=None,
#                                                                  stop_words=None,
#                                                                  strip_accents=None,
#                                                                  token_p...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight='balanced',
#                                         criterion='entropy', max_depth=500,
#                                         max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=2,
#                                         min_samples_split=10,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=500, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
param_grid = {
    'features__ngram__ngram_range': [(1,1), (1,2), (1,3)],
    'features__ngram__max_features': [None, 100, 250, 500, 1000, 1500, 2000, 2500, 3000],
#     'clf__n_estimators': [100, 250, 500, 750, 1000],
#     'clf__max_features': ['auto', 'log2'],
#     'clf__max_depth': [None, 100, 500, 1000],
#     'clf__min_samples_split': [2, 5, 10, 12],
#     'clf__min_samples_leaf': [1, 2, 4, 8],
#     'clf__criterion': ['gini', 'entropy'],
#     'clf__bootstrap': [True, False],
#     'clf__C': [.01, .1, 1, 10, 100],
#     'clf__class_weight': [None, 'balanced']
    'clf__alpha': [1, .1, .01, .001]
}

search = GridSearchCV(pipeline, param_grid, n_jobs=-1)
# search = RandomizedSearchCV(pipeline, param_grid, n_jobs=-1, n_iter=100)
search.fit(answerable_data[:,0], answerable_data[:,1])
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('features',
#                                         FeatureUnion(n_jobs=None,
#                                                      transformer_list=[('ngram',
#                                                                         TfidfVectorizer(analyzer='word',
#                                                                                         binary=False,
#                                                                                         decode_error='strict',
#                                                                                         dtype=<class 'numpy.float64'>,
#                                                                                         encoding='utf-8',
#                                                                                         input='content',
#                                                                                         lowercase=True,
#                                                                                         max_df=1.0,
#                                                                                         max_features=None,
#                                                                                         min_df=1,
#                                                                                         ngram_range=(1,
#                                                                                                      1),
#                                                                                         norm='l2',
#                                                                                         p...
#                                         MultinomialNB(alpha=1.0,
#                                                       class_prior=None,
#                                                       fit_prior=True))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'clf__alpha': [1, 0.1, 0.01, 0.001],
#                          'features__ngram__max_features': [None, 100, 250, 500,
#                                                            1000, 1500, 2000,
#                                                            2500, 3000],
#                          'features__ngram__ngram_range': [(1, 1), (1, 2),
#                                                           (1, 3)]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
np.mean(cross_val_score(search.best_estimator_, answerable_data[:,0], answerable_data[:,1]))
# Out:
# 0.6335483870967742

# %%
[(answerable_data[:,0][i], search.best_estimator_.predict(answerable_data[:,0])[i]) for i in range(len(answerable_data)) if search.best_estimator_.predict(answerable_data[:,0])[i] != answerable_data[:,1][i]]
# Out:
# []

# %%
len(answerable_data)
# Out:
# 153

# %%
search.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('ngram',
#                                                  CountVectorizer(analyzer='word',
#                                                                  binary=False,
#                                                                  decode_error='strict',
#                                                                  dtype=<class 'numpy.int64'>,
#                                                                  encoding='utf-8',
#                                                                  input='content',
#                                                                  lowercase=True,
#                                                                  max_df=1.0,
#                                                                  max_features=500,
#                                                                  min_df=1,
#                                                                  ngram_range=(1,
#                                                                               3),
#                                                                  preprocessor=<function answerable_preprocessor at 0x1a183b2950>,...
#                                                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                                                  tokenizer=None,
#                                                                  vocabulary=None))],
#                               transformer_weights=None, verbose=False)),
#                 ('clf',
#                  LogisticRegression(C=1, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
np.mean([len(answerable_data[:,0][i].split()) for i in range(len(answerable_data)) if answerable_data[:,1][i] == 't'])
# Out:
# 17.476923076923075

# %%
np.mean([len(answerable_data[:,0][i].split()) for i in range(len(answerable_data)) if answerable_data[:,1][i] == 'f'])
# Out:
# 9.253968253968255

# %%
np.mean([len(answerable_data[:,0][i].split()) for i in range(len(answerable_data)) if answerable_data[:,1][i] == 'c'])
# Out:
# 20.32
